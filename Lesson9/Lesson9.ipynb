# %% [markdown]
# ### Домашнее задание
# Нужно реализовать rest api на базе flask (пример https://github.com/fimochka-sudo/gb_flask_hw_api)
#
# По шагам:
# 1. выбрать себе датасет (который интересен или нравится больше всего), сделать pipeline (преобразования + модель), сохранить его на диск. Если не хочется пайплайн, то можно без него, но так вам же будет удобнее потом вызывать его из кода сервиса.
# 2. установить удобную для себя среду разработки (pycharm прекрасен - https://www.jetbrains.com/pycharm/)
# 3. научиться создавать там виртуальное окружение для python (в правом нижнем углу есть add interpreter)
# 4. для вашего проекта вам понадобится requirements.txt с пакетами. Можно за основу взять такой файл из проекта выше. Для его установки прям в pycharm можно открыть терминал и сделать pip install -r requirements.txt (находясь в корне проекта конечно же при этом)
# 5. завести себе аккаунт на guthub (если его еще нет). У самого github есть такой "hello world" по работе с ним - https://guides.github.com/activities/hello-world/
# 6. научиться запускать gunicorn (установить его конечно). Пример для проекта выше: gunicorn -w 5 -b 127.0.0.1:5000 run_server:app
# 7. итоговый проект должен содержать: 1) каталог models/ (здесь модель-пайплайн предобученная) 2) файл run_server.py (здесь основной код flask-приложения) 3) requirements.txt (список пакетов, которые у вас используются в проекте) 4) README.md (здесь какое-то описание, что вы делаете, что за данные и т.д)
# 8. (<b>Опционально</b>): front-end сервис какой-то, который умеет принимать от пользователя введеные данные и ходить в ваш api. На самом деле полезно больше вам, т.к если ваш проект будет далее развиваться (новые модели, интересные подходы), то это хороший пунктик к резюме и в принципе - строчка в портфолио)

# %% [markdown]
# ### Задача тематического моделирования заявок в чатбот

# %%
import numpy as np
import pandas as pd

from nltk.corpus import names
import nltk; nltk.download('stopwords')
# NLTK Stop words
from nltk.corpus import stopwords

import re

from pymorphy2 import MorphAnalyzer

from gensim import corpora, models
from gensim.models import CoherenceModel
from gensim.models import Phrases
from gensim.models.ldamulticore import LdaMulticore
import gensim

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sych_\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline, FeatureUnion
import dill

# %%
pd.set_option('max_colwidth', 120)
pd.set_option('display.width', 500)

# %%
data = pd.read_csv("Заявки в чатбот.csv", encoding = 'utf-16', sep=";")
data.tail(20)
# Out:
#                                                                                                                        mesTExt
# 20136  Добрый день! В базе Д11 по арт 449499 Свинина охл вес в карточке товара цена SSP и цена продажи не совпадают, ценник...
# 20137  Добрый день. Не работает апс Выключаешь его, включаешь и при включении компьютера он начинает пищать Подключился на ...
# 20138  Добрый день.В автозаказе поставщик Новозеланские продукты не открыта карточка товара код 168181 киви Голд 1шт,Новая ...
# 20139         Добрый день Не смогу сменить пароль nan но я ввожу все вернол но я ввожу все вернол ой позвоните еще раз спасибо
# 20140                      Доброго утра: Поставщик Ист Лоджистикал. Подтверждение order все на сегодня nan Спасибо Не осталось
# 20141  Добрый день Сегодня была смена юр.лица на самбери 24,при оформление РН,выдал такую ошибку и все документы пустые. na...
# 20142                                                 Доброе утро. \nПрошу перезагрузить RC-LOG59. Спасибо Получилось, спасибо
# 20143  Здравствуйте! ПОдскажите, пожалуйста, как перевести поставщика к EDI? хочет работать так я могу ему направить ДС о п...
# 20144  Да Добрый день.\nНе могу свести заказ, не которые вз не подтягиваются в формирование сводного заказа, например с 01,...
# 20145  Добрый день! Прошу помочь в настройке работы почты на удаленном доступе. Утром подключилась, как обычно, открылись п...
# 20146                                                                   nan Добрый день. Заказ оплатили вчера, когда доставка?
# 20147             Доброе утро. Проблема nan nan Ещё поддон nan nan nan nan nan Как успехи? Благодарю за помощь. Все принялось.
# 20148  Добрый день. Коллеги, можно по задачи 848505 ускорить обмен между базами СУТ и ВДРУГ Базы СУТ и ВД «Сейчас можно лиш...
# 20149            Сейчас проверю Еще не было приходов В чем была проблема? Я на выходном. Пока не получила обратную связь от гм
# 20150  Добрый день . Сейчас на с25 выгрузился Истлоджистик, по данному шк/к поддон принять не получается . Сканер шк. Считы...
# 20151                                                                                             Моя почта заблокированна Нет
# 20152              Добрый день! У меня не уходят письма, подскажите что делать? Они в исходящих, Новые письма приходят Спасибо
# 20153  Добрый день, сегодня в ЛУП в промо  № 41716 были внесены изменения, добавили С-26 и С-32 на позицию 94818 Апельсин Е...
# 20154  Добрый день. Управляющий д10 Эрикайкина Лариса. Заказы на поставщика ТК Молоко не выгружаются в 1с из консалидирован...
# 20155                                                                                             nan nan Давайте. Сюда можно?

# %%
class TextImputer(BaseEstimator, TransformerMixin):
    def __init__(self, key, value):
        self.key = key
        self.value = value
        
    def get_stopwords(self):
        russian_stopwords = stopwords.words("russian")
        df_sw = pd.read_csv('stopwords.csv', encoding = 'utf-8', sep=";")
        for index, row in df_sw.iterrows():
            russian_stopwords.append(row['stopword'])
        return russian_stopwords
        
    def to_lemmatize2(self, df, key):
        all_word_str = " ".join(df[key])
        all_word_list = all_word_str.split()
        all_unique_word = pd.Series(all_word_list).unique()
        lemmatized_word_dict = {}
        lemmatizer = MorphAnalyzer()
        for word in all_unique_word:
            lemmatized_word_dict[word] = lemmatizer.normal_forms(word)[0]
        lemm_func = lambda text: ' '.join([lemmatized_word_dict[word] for word in text.split()])
        df[key] = df[key].apply(lemm_func)
        return df, all_unique_word
    
    def fit(self, X, y=None):
        return self
    def transform(self, X):

        X[self.key] = X[self.key].replace('—','-')
        
        #1. удаляем пунктуацию
        deleted_symbols = r'[\\\\\'[\]!"$%&()*+,-./:;<=>?№@^_`{|}~«»\n]'  
        func = lambda text : re.sub(deleted_symbols, ' ', str(text))
        X[self.key] = X[self.key].apply(func)
        
        #2. удалим смайлики
        emoji_pattern = re.compile("["
            u"\U0001F600-\U0001F64F"  # emoticons
            u"\U0001F300-\U0001F5FF"  # symbols & pictographs
            u"\U0001F680-\U0001F6FF"  # transport & map symbols
            u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags=re.UNICODE)
        func = lambda text : re.sub(emoji_pattern, ' ', str(text))
        X[self.key] = X[self.key].apply(func)
        
        #3. удалим отдельно стоящие цифры
        func = lambda text : ' '.join([elem for elem in str(text).split(' ') if elem.isdigit() == False])   
        X[self.key] = X[self.key].apply(func)
        
        #4. приводим к нижнему регистру
        X[self.key] = X[self.key].apply(lambda text : text.lower())
        
        #5. лемматизация (приводим слова к начальной форме)
        X, _ = self.to_lemmatize2(X, self.key)
        
        #6. удаляем стоп слова
        sw = self.get_stopwords()
        func = lambda text : ' '.join([elem for elem in str(text).split(' ') if elem not in sw and not elem in ['nan', np.nan]])   
        X[self.key] = X[self.key].apply(func)
        
        return X 
    
class ColumnSelector(BaseEstimator, TransformerMixin):
    """
    Transformer to select a single column from the data frame to perform additional transformations on
    """
    def __init__(self, key):
        self.key = key

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        #приведем к виду списка списков, потом этот список списков пойдет в модель LDA
        lst = X[self.key].to_list()
        texts = []
        for i in range(len(lst)):    
            texts.append(lst[i].split(' '))
        return texts
    
class myLDA():
    def __init__(self, num_topics, passes, alpha, eta):
        
        self.num_topics=16
        self.passes=20
        self.alpha=1.25
        self.eta=1.25
        #self.lda = LdaMulticore.load(lda_path)
        #self.bigram_path = bigram_path
        #self.trigram_path = trigram_path
    
    def fit(self, texts):
        
        text_clean = texts.copy()
        bigram = Phrases(text_clean) # Создаем биграммы на основе корпуса
        trigram = Phrases(bigram[text_clean])# Создаем триграммы на основе корпуса
        
        for idx in range(len(text_clean)):
            for token in bigram[text_clean[idx]]:
                if '_' in token:
                    # Токен это би грамма, добавим в документ.
                    text_clean[idx].append(token)
            for token in trigram[texts[idx]]:
                if '_' in token:
                    # Токен это три грамма, добавим в документ.
                    text_clean[idx].append(token)
        
        dictionary_bt = corpora.Dictionary(text_clean)   # составляем словарь
        dictionary_bt.filter_extremes(no_below=10, no_above=0.1)
        corpus_bt = [dictionary_bt.doc2bow(text) for text in text_clean]  # составляем корпус документов
        model = LdaMulticore(corpus=corpus_bt, id2word=dictionary_bt, self.num_topics, self.passes, self.alpha, self.eta)
        return model
    
    def transform(self, X)
        return self
    
    def predict(self, text):
        #clean_text = self.clean(text)
        #bigram = self.bigram([clean_text])
        #new_review_bow = self.dictionary.doc2bow(bigram[0])
        #new_review_lda = self.lda[new_review_bow]
        #return sorted(new_review_lda, reverse=True, key=itemgetter(1))
        return 0

# %%
#example
description = Pipeline([
                ('imputer', TextImputer('mesTExt', '')),
                ('selector', ColumnSelector(key='mesTExt')),
                ('lda', myLDA())
            ])

description.fit(data)
description.transform(data)
# Out:
# [[''],
#  ['сломаться',
#   'ноготь',
#   'сломать',
#   'ноготь',
#   'сломать',
#   'ноготь',
#   'сломаться',
#   'ноутбук',
#   'весь',
#   'пропасть',
#   'делать',
#   'вообще',
#   'чушь',
#   'помочь',
#   'срочно',
#   'вообще',
#   'чушь',
#   'помочь',
#   'срочно',
#   'ерп',
#   'автозаказ',
#   'сок',
#   'протечь',
#   'сок',
#   'протечь'],
#  ['хабаровск', 'сломаться', 'ноутбук', 'рабртаять', 'автозаказ', 'автозаказ'],
#  ['сок',
#   'протечь',
#   'сломать',
#   'ноутбук',
#   'ерп',
#   'висеть',
#   'ерп',
#   'висеть',
#   'ерп',
#   'висеть',
#   'оператор',
#   'добавить',
#   'номер',
#   'телефон',
#   'личный',
#   'кабинет',
#   'парль'],
#  [''],
#  ['ерп', 'ерп', 'ерп', 'упасть', 'напрочь'],
#  ['ерп',
#   'ерп',
#   'ерп',
#   'чинить',
#   'сволочь',
#   'зависнуть',
#   'ерп',
#   'загружаться',
#   'заказ',
#   'проводиться',
#   'это',
#   'пользователь',
#   'каждый',
#   'делать'],
#  ['висеть',
#   'ерп',
#   'висеть',
#   'ерп',
#   'весить',
#   'erp',
#   'висеть',
#   'програм',
#   'ерп',
#   'загружаться',
#   'заказ',
#   'заказ',
#   'проводиться',
#   'документ',
#   'еклмный',
#   'проводиться',
#   'документ',
#   'ешка',
#   'матрёшка',
#   'висеть',
#   'ерп',
#   'клиент'],
#  ['заказ', 'загружаться', 'проводиться', 'ерп', 'проводиться', 'ерп'],
#  ['загружаться',
#   'заказ',
#   'висеть',
#   'ерп',
#   'проверить',
#   'весь',
#   'проводиться',
#   'туда',
#   'прилетать',
#   'заявка',
#   'странно',
#   'проводиться',
#   'проводиться',
#   'документ',
#   'проводиться',
#   'спс',
#   'висеть',
#   'ерп',
#   'решить'],
#  ['заказ', 'загружаться', 'заказ', 'загружаться', 'заказ', 'проводиться'],
#  ['проводиться', 'проводиться', 'проводиться'],
#  ['висеть', 'ерп', 'блин'],
#  ['реализация',
#   'заказ',
#   'проводиться',
#   'первое',
#   'приходиться',
#   'выходить',
#   'заходить',
#   'постоянно',
#   'заново',
#   'заявка',
#   'это',
#   'проводиться',
#   'вылетать',
#   'ошибка'],
#  ['выкидывать', 'база'],
#  ['висеть',
#   'база',
#   'открытие',
#   'вкладка',
#   'открытие',
#   'заказ',
#   'тд',
#   'немного',
#   'хороший',
#   'подвисать'],
#  ['висеть',
#   'ерп',
#   'проведение',
#   'реализация',
#   'хороший',
#   'плохой',
#   'стать',
#   'время',
#   'перезаходить',
#   'увы',
#   'поздний',
#   'попробовать',
#   'перезапуститься',
#   'значительно',
#   'живой',
#   'двигаться',
#   'процесс',
#   'агент',
#   'галина',
#   'заявка',
#   'ерп',
#   'is',
#   '\u200d♀',
#   'заказ',
#   'загрузить',
#   'сорри',
#   'простить',
#   'бот'],
#  ['погружаться',
#   'заказ',
#   'выкидывать',
#   'база',
#   'николайчук',
#   'анастасий',
#   'закрыть'],
#  ['выбрасывать', 'база', 'бурдинской', 'ян', 'скоро'],
#  ['находка', 'доступ', 'интернет', 'весь', 'программа', 'данил', 'нина'],
#  ['проверка', 'проверка', 'связь'],
#  ['тест',
#   'висеть',
#   'тсд',
#   'открытый',
#   'чат',
#   'оператор',
#   'шт',
#   'клиент',
#   'дмитрий',
#   'крюков',
#   'оператор',
#   'случиться',
#   'чат',
#   'видеть',
#   'это',
#   'видеть',
#   'текст',
#   'свой',
#   'запрос',
#   'это',
#   'норма',
#   'весь',
#   'увидеть',
#   'получаться',
#   'запрос',
#   'висеть',
#   'тсд',
#   'прийти',
#   'дежурный',
#   'напрямую',
#   '—',
#   'важный',
#   'дежурный',
#   'точно',
#   'пропустить',
#   'запрос',
#   'точно',
#   'видеть',
#   'понять',
#   'виталя',
#   'передать',
#   'передать',
#   'увидеть',
#   'отвечать',
#   'убедиться',
#   'сразу',
#   'увидеть',
#   'видно',
#   'сразу',
#   'сообщение',
#   'пришлый',
#   'перенести',
#   'ночью',
#   'виталя',
#   'спать',
#   'говорить',
#   'общий',
#   'чат',
#   'увидеть',
#   'весь',
#   'равно',
#   '—',
#   'сразу'],
#  ['ерп',
#   'весь',
#   'это',
#   'фейл',
#   'обязательно',
#   'исправить',
#   'тест',
#   'ерп',
#   'просить',
#   'отреагировать'],
#  ['цена',
#   'висеть',
#   'база',
#   'посмотреть',
#   'весь',
#   'операция',
#   'весь',
#   'нормальный'],
#  ['прогружаться',
#   'заказ',
#   'большой',
#   'медленно',
#   'база',
#   'сильно',
#   'висеть',
#   'база',
#   'отдел',
#   'координация',
#   'сильно',
#   'висеть',
#   'база',
#   'прогружаться',
#   'заказ'],
#  ['зависнуть', 'база', 'сколько', 'ждать', 'нормальный'],
#  ['висеть', 'ерп'],
#  ['сильно',
#   'висеть',
#   'база',
#   'весь',
#   'отлично',
#   'долго',
#   'проводться',
#   'зааз',
#   'плохо',
#   'база',
#   'ответ',
#   'минута',
#   'окончание',
#   'выписка',
#   'агент',
#   'золотов',
#   'светдать',
#   'погрузить',
#   'заказ',
#   'писать',
#   'оператор',
#   'ответ',
#   'почему',
#   'ответ',
#   'весь',
#   'прогрузить',
#   'рука',
#   'агент',
#   'весь',
#   'решить',
#   'рука'],
#  ['ерп',
#   'видимо',
#   'зависнуть',
#   'рейс',
#   'запихнуть',
#   'заказ',
#   'весь',
#   'отлично'],
#  ['сильно',
#   'висеть',
#   'программа',
#   'заявка',
#   'медленно',
#   'обрабатываться',
#   'хороший',
#   'подвисать',
#   'стать',
#   'намного',
#   'хороший',
#   'завтра',
#   'проверить'],
#  ['висеть',
#   'ерп',
#   'вообще',
#   'происходить',
#   'реализация',
#   'открыть',
#   'колесико',
#   'крутиться',
#   'стать',
#   'хороший',
#   'понаблюдать',
#   'весь'],
#  ['тест',
#   'гресиков',
#   'время',
#   'реакция',
#   'норма',
#   'идентификация',
#   'ад',
#   'номер',
#   'тело',
#   'нужно',
#   'зуп',
#   'жёстко',
#   'связать',
#   'ещё',
#   'неопознанный',
#   'номер',
#   'ответ',
#   'запрашивать',
#   '1й',
#   'имя',
#   'фамилия'],
#  ['висеть',
#   'база',
#   'долго',
#   'рассчитывать',
#   'остаток',
#   'проведение',
#   'хороший'],
#  ['зайти'],
#  ['тест',
#   'тест',
#   'тест',
#   'просить',
#   'игнорировать',
#   'данный',
#   'обращение',
#   'тест',
#   'просить',
#   'игнорировать',
#   'данный',
#   'обращение',
#   'тест',
#   'просить',
#   'игнорировать',
#   'данный',
#   'обращение'],
#  ['ерп',
#   'кэш',
#   'почистить',
#   'научить',
#   'весь',
#   'равно',
#   'аварийный',
#   'завершение',
#   'почистить',
#   'кэш',
#   'запустить',
#   'ерп',
#   'ткнуть',
#   'отчёт',
#   'задолженность',
#   'весь',
#   'объявление',
#   'весь',
#   'висеть',
#   'ерп',
#   'запускать',
#   'начать',
#   'сеть',
#   'запуститься',
#   'общий',
#   'домой',
#   'сила',
#   'ждать',
#   'проверить',
#   'ничто',
#   'смочь',
#   'завтрашний',
#   'заработать',
#   'ерп',
#   'кстати',
#   'минута'],
#  ['тест', 'просить', 'игнорировать'],
#  ['выгружаться', 'ерп', 'заказ', 'марс', 'шоколад', 'ван', 'мелла', 'сахалин'],
#  ['зависать',
#   'база',
#   'попрежний',
#   'зависать',
#   'намного',
#   'хороший',
#   'заявка',
#   'падать',
#   'юнилевера',
#   'аданичкин',
#   'татьяна',
#   'голыгин',
#   'ксюша',
#   'яскевич',
#   'мария',
#   'прислать'],
#  ['повиснуть', 'вмс', 'тсд', 'весь'],
#  ['выгружаться', 'заказ', 'ерп', 'ван', 'мелла', 'сахалин', 'выгружаться'],
#  ['ерп',
#   'происходить',
#   'рабочий',
#   'стол',
#   'выбрасывать',
#   'полчаса',
#   'начать',
#   'работа',
#   'зайти',
#   'удалённый',
#   'аналогично',
#   'ау',
#   'шалим',
#   'ерп',
#   'запуститься'],
#  ['решение',
#   'романенков',
#   'анна',
#   'закрыть',
#   'хороший',
#   'выбросить',
#   'база',
#   'весь',
#   'зайти'],
#  ['прогружаться', 'заказ', 'выкидывать', 'база', 'весь'],
#  ['очный',
#   'долго',
#   'проводяться',
#   'заказ',
#   'хороший',
#   'база',
#   'выбрасывать',
#   'дать',
#   'ошибка',
#   'весь',
#   'весь'],
#  ['выкидывать', 'база', 'выкидывать', 'база', 'весь', 'заработать'],
#  ['совгавань', 'ерп'],
#  ['открыть',
#   'ерп',
#   'выдавать',
#   'ошибка',
#   'пользователь',
#   'воронцов',
#   'заслать'],
#  ['выкинуть',
#   'ерп',
#   'давать',
#   'зайти',
#   'весь',
#   'филиал',
#   'ошибка',
#   'ниже',
#   'фото'],
#  ['весь',
#   'отдел',
#   'координация',
#   'вышибить',
#   'ерп',
#   'писать',
#   'причина',
#   'вроде',
#   'входить'],
#  ['зависать',
#   'база',
#   'ошибка',
#   'устранить',
#   'падать',
#   'заявка',
#   'весь',
#   'направление',
#   'юнилевера',
#   'славянка',
#   'ваннмелла',
#   'марс',
#   'шоколад',
#   'отписаться',
#   'прийти',
#   'заявка',
#   'прогружаться',
#   'большой',
#   'профилактика',
#   'прогружаться',
#   'заявка',
#   'программа',
#   'прогружать',
#   'ручной',
#   'например',
#   'бахитовый',
#   'татьяна',
#   'бахитовый',
#   'полностью',
#   'прогрузиться',
#   'урушева',
#   'оксана',
#   'висеть'],
#  ['сильно', 'виснуть', 'база', 'стать', 'лучьша'],
#  ['долго', 'проводиться', 'заказ', 'посмотреть', 'стать', 'хороший'],
#  ['зайти',
#   'заявка',
#   'понамарево',
#   'ксения',
#   'просить',
#   'прощение',
#   'это',
#   'документ',
#   'продажа',
#   'pos',
#   'материал',
#   'эхуп',
#   'перезагружать',
#   'ещё',
#   'весь'],
#  ['висеть',
#   'ерп',
#   'долгий',
#   'отклик',
#   'переход',
#   'окно',
#   'хороший',
#   'сервер',
#   'трехэтажный',
#   'дом'],
#  ['профилактика',
#   'момент',
#   'выполнение',
#   'задача',
#   'инвентаризация',
#   'отваливаться',
#   'постоянно',
#   'соединение',
#   'закрывать'],
#  ['зависнуть', 'вмс', 'компьютер', 'терминал', 'весь', 'заработать'],
#  ['ерп'],
#  ['висеть',
#   'ерп',
#   'просить',
#   'посмотреть',
#   'весь',
#   'спс',
#   'сказать',
#   'отписаться',
#   'сразу',
#   'увидеть',
#   'предыдущий',
#   'заявка'],
#  ['долго', 'проводяться', 'заказ'],
#  ['висеть', 'прогрузить', 'заявка'],
#  ['делать', 'выключиться', 'ноутбук', 'просто', 'минута', 'включиться'],
#  ['тест', 'тест'],
#  ['висеть', 'ерп', 'свидание'],
#  ['тест'],
#  ['ерп',
#   'заявка',
#   'прогрузиться',
#   'ошибка',
#   'распечатка',
#   'чек',
#   'нужно',
#   'продлить',
#   'план',
#   'посещение',
#   'касса',
#   'открывать',
#   'смена',
#   'тест',
#   'тест',
#   'лана',
#   'посещение',
#   'план',
#   'посещение',
#   'ошибка',
#   'распечатка',
#   'чек'],
#  ['ерп', 'висеть', 'тест', 'шалим', 'приходить', 'уведомление'],
#  ['долго',
#   'проводяться',
#   'зааз',
#   'расчитываться',
#   'остаток',
#   'долго',
#   'проводяться',
#   'зааз',
#   'расчитываться',
#   'остаток'],
#  ['прогружаться', 'заявка'],
#  ['приниматься',
#   'сообщение',
#   'мэ',
#   'специалист',
#   'ит',
#   'продлить',
#   'план',
#   'посещение'],
#  ['прогружаться', 'заказ'],
#  [''],
#  ['тест',
#   'ошибка',
#   'распечатка',
#   'чек',
#   'тест',
#   'тест',
#   'тест',
#   'прогружаться',
#   'заявка',
#   'прогружаться',
#   'заявка',
#   'тест'],
#  ['прогружаться',
#   'заявка',
#   'снова',
#   'прогрузка',
#   'заявка',
#   'это',
#   'агент',
#   'весь',
#   'остальной',
#   'висеть'],
#  ['ставить',
#   'товар',
#   'приход',
#   'провести',
#   'приходник',
#   'сбрасывать',
#   'срасибр',
#   'минута',
#   'начинать',
#   'проводить',
#   'проводить',
#   'писать',
#   'пытаться',
#   'записать',
#   'записывать',
#   'экупа',
#   'это',
#   'заказ',
#   'перемещение',
#   'сохацкай',
#   'ольга',
#   'владимир',
#   'это',
#   'ещё',
#   'рогов',
#   'митрошкин',
#   'ошибка',
#   'просто',
#   'проводить',
#   'приходный',
#   'ордер',
#   'записывать',
#   'всн'],
#  ['долго',
#   'проводяться',
#   'заказ',
#   'расчитываться',
#   'остаток',
#   'заказ',
#   'провозить',
#   'жаловаться',
#   'база',
#   'долго',
#   'проводить',
#   'заказ',
#   'долго',
#   'расчитываться',
#   'остаток',
#   'весь',
#   'нормаоьный',
#   'стать',
#   'хороший'],
#  ['прогружаться', 'заказ'],
#  ['папка', 'скс'],
#  ['долго',
#   'обрабатываться',
#   'заказ',
#   'суровый',
#   'ирина',
#   'уйти',
#   'стать',
#   'намного',
#   'хороший'],
#  ['прогружаться', 'заказ', 'весь', 'прогрузиться'],
#  ['арма',
#   'склад',
#   'выпускать',
#   'расходный',
#   'ордер',
#   'сборщик',
#   'кипрая',
#   'александр',
#   'сергей',
#   'арма',
#   'выдавать',
#   'ошибка',
#   'ссылаться',
#   'ро',
#   'уп',
#   'ро',
#   'обработать',
#   'сборщик',
#   'статус',
#   'проверка',
#   'координатор',
#   'ерп',
#   'отменяться',
#   'строка',
#   'проверка',
#   'весь',
#   'цепочка',
#   'помечаться',
#   'удаление',
#   'вмс',
#   'поэтому',
#   'это',
#   'весь',
#   'оператор',
#   'кипрая',
#   'печатать',
#   'подсказать',
#   'привести',
#   'это',
#   'вычерк',
#   'делать',
#   'оператор',
#   'ерп',
#   'сборщик',
#   'ставить',
#   'статус',
#   'проверка',
#   'оператор',
#   'делать',
#   'отмена',
#   'строка',
#   'проводить',
#   'отмена',
#   'ро',
#   'переводиться',
#   'статус',
#   'отгрузка',
#   'автоматически',
#   'удаляться',
#   'весь',
#   'цепочка',
#   'документ',
#   'история',
#   'необычный',
#   'отгрузка',
#   'вставать',
#   'автоматически',
#   'заканчиваться',
#   'проверка',
#   'нужно',
#   'оформить',
#   'складской',
#   'вычерк',
#   'оператор',
#   'склад',
#   'должный',
#   'перевести',
#   'ро',
#   'статус',
#   'проверка',
#   'это',
#   'оператор',
#   'проводить',
#   'проверка',
#   'склад',
#   'арма',
#   'должный',
#   'проводить',
#   'вычерк',
#   'слышать',
#   'возможность',
#   'вопрос',
#   'решить',
#   'просто',
#   'хотеться',
#   'разобраться',
#   'дальнейший',
#   'возникать',
#   'ошибка',
#   'скорее',
#   'склад',
#   'отчитывать',
#   'ро',
#   'нести',
#   'вычерк',
#   'оформление',
#   'приходиться',
#   'откатывать',
#   'статус',
#   'назад',
#   'отгрузка',
#   'проверка',
#   'оформлять',
#   'вычерк'],
#  ['зайти', 'ерп', 'заслать', 'база'],
#  ['прогрузить', 'заказ'],
#  ['вопрос',
#   'работа',
#   'горячий',
#   'линия',
#   'почему',
#   'агент',
#   'дозвониться',
#   'гл',
#   'вопрос',
#   'мэ',
#   'провести',
#   'оплата',
#   'клиент',
#   'стопа',
#   'отгружаться',
#   'агент',
#   'галина'],
#  ['тест'],
#  ['ерп',
#   'долго',
#   'вылетать',
#   'ровно',
#   'минута',
#   'кэш',
#   'чистить',
#   'ещё',
#   'жёсткий',
#   'диск',
#   'нужно',
#   'почистить',
#   'весь',
#   'ви',
#   'фи',
#   'хабаровский',
#   'филиал',
#   'вылетать',
#   'каждый',
#   'минута',
#   'чат',
#   'бот'],
#  ['прогружаться',
#   'заказ',
#   'агент',
#   'комаров',
#   'владимир',
#   'весь',
#   'прогрузиться',
#   'зависнуть',
#   'база',
#   'нормальный'],
#  ['прогрузиться', 'заказ'],
#  ['висеть', 'база', 'весь', 'хороший'],
#  ['минута',
#   'висеть',
#   'заяаки',
#   'прогрузить',
#   'шестаков',
#   'людмила',
#   'заявка',
#   'долго',
#   'висеть',
#   'прогрузить',
#   'прогрузить',
#   'ничто',
#   'измениться',
#   'весь'],
#  ['долго', 'заказ', 'проводяться', 'вроде', 'норма', 'затупать', 'написать'],
#  ['касса',
#   'ют',
#   'камчатка',
#   'хотеть',
#   'присваивать',
#   'номер',
#   'чек',
#   'пко',
#   'ючуп',
#   'сумма',
#   'присвоить',
#   'номер',
#   'весь'],
#  ['провести',
#   'релиз',
#   'ошибка',
#   'писать',
#   'склад',
#   'марс',
#   'шоколад',
#   'ричь',
#   'провестись',
#   'весь'],
#  ['сильно',
#   'висеть',
#   'база',
#   'посмотреть',
#   'синицын',
#   'татьяна',
#   'возражение',
#   'весь',
#   'ещё',
#   'заходить',
#   'база',
#   'летать',
#   'большой'],
#  ['касса',
#   'эник',
#   'артём',
#   'z',
#   'отчёт',
#   'смена',
#   'закрытый',
#   'ерп',
#   'стоить',
#   'статус',
#   'открытый',
#   'закрыться'],
#  ['прогружаться', 'заказ', 'судак'],
#  ['проверка',
#   'спать',
#   'дать',
#   'поиграться',
#   'проверка',
#   'забирать',
#   'это',
#   'сообщение',
#   'изучать',
#   'чат',
#   'бот',
#   'ничто',
#   'случиться',
#   'закрывать'],
#  ['проверка', 'забирать', 'это', 'сообщение', 'изучать', 'чат', 'бот'],
#  ['эник', 'хабаровск', 'ничто', 'уходить'],
#  ['выгрузка',
#   'марс',
#   'корма',
#   'марс',
#   'шоколад',
#   'ничто',
#   'марс',
#   'корма',
#   'падать',
#   'марс',
#   'шоколад'],
#  ['прогружаться',
#   'заказ',
#   'агент',
#   'комаров',
#   'ходжер',
#   'прошружаться',
#   'заявка',
#   'весь',
#   'хоршо',
#   'это',
#   'отписаться',
#   'заказ',
#   'весь'],
#  ['артём',
#   'невозможно',
#   'открыть',
#   'смена',
#   'касса',
#   'ют',
#   'дв',
#   'артём',
#   'весь'],
#  ['совгавань', 'эник'],
#  ['касса', 'совгавань', 'маркетереть', 'эник', 'починить'],
#  ['тест'],
#  ['вчерашний',
#   'отписаться',
#   'снова',
#   'оператор',
#   'весь',
#   'написать',
#   'прогружаться',
#   'заявка',
#   'судак'],
#  ['тест', 'напасть', 'кассир', 'магазин', 'помощь'],
#  ['падать',
#   'заявка',
#   'торговый',
#   'представитель',
#   'сон',
#   'наталья',
#   'заявка',
#   'выгрузиться'],
#  ['прогрузиться', 'заказ', 'большой'],
#  ['эник',
#   'благовещенск',
#   'ошибка',
#   'идти',
#   'печать',
#   'чековый',
#   'весь',
#   'починить'],
#  ['выгружаться',
#   'заявка',
#   'сон',
#   'наталья',
#   'падать',
#   'заявка',
#   'марс',
#   'корма',
#   'марс',
#   'шоколад',
#   'весь',
#   'извинить',
#   'падать',
#   'заявка',
#   'смирнов',
#   'дарья'],
#  ['зайти', 'обмен', 'заявкамиоптскс', 'проверять', 'угрюм', 'вроде', 'весь'],
#  ['падать',
#   'заявка',
#   'торговый',
#   'представитель',
#   'урушева',
#   'оксана',
#   'упасть',
#   'заявка',
#   'падать',
#   'заявка',
#   'смирнов',
#   'дарья',
#   'оринять',
#   'заявка',
#   'должный',
#   'база',
#   'ниодный',
#   'заявка',
#   'дарья'],
#  ['касса',
#   'ют',
#   'камчатка',
#   'выдавать',
#   'ошибка',
#   'снова',
#   'касса',
#   'эник',
#   'камчатка',
#   'присвоить',
#   'номер',
#   'пко',
#   'эчуп',
#   'сумма',
#   'присвоить',
#   'номер',
#   'ничто',
#   'измениться',
#   'эник',
#   'появиться',
#   'номер',
#   'ют',
#   'выдавать',
#   'большой',
#   'помощь'],
#  ['нужный', 'доступ', 'помочь', 'весь'],
#  ['прогружаться', 'заказ'],
#  ['марченко',
#   'прогружаться',
#   'заказ',
#   'весь',
#   'отлично',
#   'евсейчик',
#   'прогружаться'],
#  ['ошибка',
#   'эник',
#   'благовещенск',
#   'норма',
#   'ошибка',
#   'энтерит',
#   'благовещенск',
#   'эник'],
#  ['подсказать', 'дать', 'база', 'wms', 'работа', 'стоить', 'база'],
#  ['гусев',
#   'елена',
#   'николай',
#   'заблокироваться',
#   'учётный',
#   'запись',
#   'начать',
#   'помочь',
#   'закрыть',
#   'заявка',
#   'сервис',
#   'деск',
#   'помощь'],
#  ['выгрузка',
#   'марс',
#   'корма',
#   'иметь',
#   'вид',
#   'заказ',
#   '—',
#   'агент',
#   'говорят',
#   'скидывать',
#   'заявка',
#   'самый',
#   'база',
#   'видеть',
#   'зобаев',
#   'дворкин',
#   'моторина',
#   'это',
#   'создать',
#   'вручную',
#   'агент',
#   'заявка',
#   'видеть',
#   'заказ'],
#  ['писать', 'ранее', 'вообще', 'проходить', 'май', 'весь'],
#  ['проект',
#   'монделиса',
#   'прогружаться',
#   'заказ',
#   'ерп',
#   'заказ',
#   'кидать',
#   'васть',
#   'вайс',
#   'проект',
#   'монделиса',
#   'прогружаться',
#   'заказ',
#   'ерп',
#   'заказ',
#   'кидать',
#   'вайс',
#   'казыбаев',
#   'ян',
#   'бугаев',
#   'алин'],
#  ['прогружаться', 'заказ'],
#  ['касса', 'ют', 'дв', 'артём'],
#  ['открыть',
#   'смена',
#   'выдавать',
#   'ошибка',
#   'касса',
#   'комп',
#   'перезагружать',
#   'эник',
#   'совгавань'],
#  ['прогрузить', 'заказ', 'ричь', 'заказ', 'упасть', 'висеть', 'минута'],
#  ['тест', 'тест'],
#  [''],
#  [''],
#  ['касса',
#   'ют',
#   'камчатка',
#   'хотеть',
#   'присваивать',
#   'номер',
#   'пко',
#   'ючуп',
#   'сумма',
#   'присвоить',
#   'номер'],
#  ['тест', 'весь'],
#  ['марченко',
#   'прогружаться',
#   'заказ',
#   'лысяк',
#   'заказ',
#   'прогружаться',
#   'хон',
#   'прогрузиться',
#   'заказ',
#   'ходжер',
#   'прогрузиться',
#   'заявка',
#   'денис',
#   'ой',
#   'извинить',
#   'торопиться',
#   'глянуть',
#   'никак',
#   'комаров',
#   'владимир',
#   'прогружаться',
#   'заказ',
#   'написать',
#   'это',
#   'коментарий',
#   'весь',
#   'прогруить'],
#  ['прогружаться',
#   'заказ',
#   'сильно',
#   'виснуть',
#   'база',
#   'ещё',
#   'база',
#   'подвисать',
#   'прогрузить',
#   'весь'],
#  ['начинать'],
#  ['висеть', 'конфигуратор', 'поступить', 'начинать'],
#  ['снова',
#   'падать',
#   'заявка',
#   'марс',
#   'корма',
#   'марс',
#   'шоколад',
#   'падать',
#   'заявка',
#   'ванна',
#   'мелла',
#   'никитин',
#   'евгеничн',
#   'появиться'],
#  ['возможно',
#   'сэд',
#   'долго',
#   'грузиться',
#   'страница',
#   'ветошный',
#   'vl',
#   'sklad02',
#   'немного',
#   'тупить',
#   'нормальный'],
#  ['автозаказ', 'весь'],
#  ['1с', 'программа', 'выкинуть', 'запускать', 'это', 'весь', 'висеть'],
#  ['сильно',
#   'виснуть',
#   'база',
#   'посмотреть',
#   'прогружаться',
#   'заказ',
#   'прогружаться',
#   'заказ'],
#  ['купить',
#   'пиво',
#   'утром',
#   'четверг',
#   'знак',
#   'сири',
#   'тестовый',
#   'it',
#   'dev',
#   'говорить',
#   'тестовый'],
#  ['автозаказ',
#   'звать',
#   'иосиф',
#   'расстрелять',
#   'это',
#   'валли',
#   'профилактика'],
#  ['поставить', 'приходник', 'отметка', 'наличие', 'чек', 'номер', 'весь'],
#  ['посмотреть', 'сделать', 'сильно', 'виснуть', 'база', 'хороший', 'стать'],
#  ['долго',
#   'реализовать',
#   'заказ',
#   'реализоваться',
#   'зказ',
#   'долго',
#   'хороший'],
#  ['ошибка'],
#  ['заявка', 'прогружаться', 'минута'],
#  ['закрыть', 'смена', 'маркетереть', 'совгавань'],
#  ['тест'],
#  ['смена', 'закрыться', 'весь', 'перезагружать', 'маркетереть', 'совгавань'],
#  ['ошибка', 'эник', 'благовещенск', 'норма'],
#  ['замена', 'фн', 'трегубова', 'анастасий'],
#  ['проект',
#   'монжделиза',
#   'выгружаться',
#   'заявка',
#   'агент',
#   'скидывать',
#   'вайс',
#   'агент',
#   'начать',
#   'скидывать',
#   'заявка',
#   'агент',
#   'заявка',
#   'весь'],
#  ['посмотреть', 'сделать', 'сильно', 'виснуть', 'база', 'хороший'],
#  ['ау'],
#  ['прогружаться', 'заявка'],
#  ['касса',
#   'эник',
#   'камчатка',
#   'замена',
#   'фискальный',
#   'память',
#   'печатать',
#   'чек',
#   'июнь',
#   'хотя',
#   'смена',
#   'открыть',
#   'нормальный',
#   'выпускать',
#   'верхний',
#   'часть',
#   'чек',
#   'писать',
#   'функция',
#   'выполнимый',
#   'дать',
#   'статус',
#   'это',
#   'фотография',
#   'попробовать',
#   'успеть',
#   'сфотографировать'],
#  ['касса', 'печатать', 'фио', 'агент', 'пречка', 'ошибка'],
#  ['это', 'значит', 'подсказать', 'дегтярев', 'ооо', 'эник', 'благовещенск'],
#  ['тест', 'аушко'],
#  ['давать',
#   'провести',
#   'реализация',
#   'заказ',
#   'весь',
#   'выложить',
#   'скрин',
#   'просто',
#   'проводиться',
#   'заказ',
#   'уюуп',
#   'ждать',
#   'минута',
#   'база',
#   'проф',
#   'пусть',
#   'прийти',
#   '—',
#   'беда',
#   'проф',
#   'параллельно',
#   'номер',
#   'люба',
#   '—',
#   'эсуп',
#   'база',
#   'забрать',
#   'устранение',
#   'ожидать',
#   '—',
#   'надолго',
#   'подсказать',
#   'долго',
#   'ждать',
#   'заявка',
#   'прогружаться',
#   'прогружаться',
#   'ручной'],
#  ['ещё',
#   'прогрузить',
#   'заказ',
#   'получаться',
#   'повесть',
#   'заказ',
#   'прогрузить',
#   'заказ',
#   'прогрузить',
#   'заказ',
#   'прогрузить',
#   'заказ',
#   'прогрузить'],
#  ['заказ',
#   'проводяться',
#   'долго',
#   'база',
#   'ходжер',
#   'женис',
#   'прогрузиться',
#   'заказ',
#   'хон',
#   'прогрузиться',
#   'заказ',
#   'лысяк',
#   'прогрузиться',
#   'заказ',
#   'ответ',
#   'заказ',
#   'загружаться'],
#  ['кна',
#   'перезагрузка',
#   'ерп',
#   'проводить',
#   'заказ',
#   'виктория',
#   'долго',
#   'ждать',
#   'спс',
#   'подсказать',
#   'пжл',
#   'долго',
#   'ерп',
#   'спс'],
#  ['проводиться',
#   'заказ',
#   'территория',
#   'благовещенск',
#   'тоня',
#   'заявка',
#   'прогружаться',
#   'автоматически',
#   'заявка',
#   'прогрузить'],
#  ['касса', 'ютадть', 'артём', 'весь', 'испопвили', 'исправить'],
#  ['ют', 'уссурийск', 'ошибка', 'анастасий', 'спс'],
#  ['маркета',
#   'ру',
#   'сахалин',
#   'выдавать',
#   'ошибка',
#   'звать',
#   'алёна',
#   'нужно',
#   'срочно',
#   'устранить',
#   'ошибка',
#   'уйти'],
#  ['складской',
#   'комплекс',
#   'кнарц',
#   'час',
#   'ерп',
#   'лаптев',
#   'виктор',
#   'ответ',
#   'вопрос',
#   'решить',
#   'переключать'],
#  ['подсказать', 'время', 'пустить', 'ерп'],
#  ['связь',
#   'ерп',
#   'прогрузиться',
#   'заказ',
#   'течение',
#   'время',
#   'заявка',
#   'висеть',
#   'прогрузить',
#   'рабочий',
#   'закончиться',
#   'прогрузить'],
#  ['весь', 'уйти'],
#  ['прогружаться', 'заказ'],
#  ['прогружаться',
#   'заказ',
#   'давать',
#   'познакомиться',
#   'бот',
#   'звать',
#   '—',
#   'мария',
#   'бот',
#   'обращение',
#   'ваш',
#   'заявка',
#   'передать',
#   'специалист',
#   'ожидать',
#   'связаться',
#   'свободный',
#   'оператор',
#   '—',
#   'ждать',
#   'весь'],
#  ['тест', 'связаться', 'бот', 'сообщение', 'интерфейс', 'люба', 'текст'],
#  ['видимый', 'закончиться', 'фискальный', 'память', 'касса', 'ют'],
#  ['эник',
#   'благовещенск',
#   'норма',
#   'добавить',
#   'бухгалтер',
#   'чек',
#   'печатать',
#   'ооо',
#   'шмель',
#   'анна',
#   'михайлов',
#   'группа',
#   'ооо',
#   'шмель',
#   'благовещенск',
#   'добавить',
#   'группа'],
#  ['работа', 'ау', 'уаца', 'ау', 'факт'],
#  ['работа', 'ау', 'проверка', 'тест', 'аушко'],
#  ['замена',
#   'фн',
#   'снять',
#   'z',
#   'отчёт',
#   'немой',
#   'номер',
#   'это',
#   'вчерашний',
#   'отчёт',
#   'сегодня',
#   'ещё',
#   'снимать',
#   'должный',
#   'отчёт',
#   'озакрытие',
#   'смена',
#   'номер'],
#  ['ха',
#   'находиться',
#   'будка',
#   'самоубийство',
#   'ехать',
#   'столица',
#   'дв',
#   'убиться',
#   'висок'],
#  ['ау', 'уауца'],
#  ['ошибка', 'весь'],
#  ['посмотреть', 'сделать', 'сильно', 'виснуть', 'база', 'стать', 'хороший'],
#  ['касса',
#   'эник',
#   'ют',
#   'z',
#   'отчёт',
#   'передать',
#   'фд',
#   'момент',
#   'замена',
#   'фискальный',
#   'память'],
#  ['вроде', 'весь', 'печатать', 'норма'],
#  ['согласование',
#   'возврат',
#   'новый',
#   'агент',
#   'активно',
#   'половина',
#   'статус',
#   'илья',
#   'козлов',
#   'илья',
#   'возврат',
#   'отклонить',
#   'агент',
#   'который',
#   'активно',
#   'половина',
#   'махмут',
#   'регин',
#   'иванов',
#   'татьяна',
#   'геннадий',
#   'лапушанский',
#   'алёна',
#   'адмаев',
#   'виталий'],
#  ['style',
#   'type',
#   'text',
#   'css',
#   'style',
#   'display',
#   'none',
#   'p',
#   'margin',
#   'top',
#   'margin',
#   'bottom',
#   'style',
#   'div',
#   'id',
#   'divtagdefaultwrapper',
#   'style',
#   'font',
#   'size',
#   '12pt',
#   'color',
#   '#000000',
#   'font',
#   'family',
#   'calibri',
#   'helvetica',
#   'sans',
#   'serif',
#   'dir',
#   'ltr',
#   'p',
#   'br',
#   'p',
#   'div',
#   'p',
#   'style',
#   'font',
#   'size',
#   '10pt',
#   'font',
#   'family',
#   'arial',
#   'span',
#   'style',
#   'font',
#   'family',
#   'calibri',
#   'span',
#   'style',
#   'font',
#   'size',
#   '11pt',
#   'span',
#   'span',
#   'p',
#   'hr',
#   'br',
#   'table',
#   'style',
#   'width',
#   '660px',
#   'tbody',
#   'tr',
#   'td',
#   'style',
#   'font',
#   'size',
#   '11pt',
#   'height',
#   '25px',
#   'font',
#   'family',
#   'calibri',
#   'width',
#   '122px',
#   'valign',
#   'top',
#   'p',
#   'style',
#   'font',
#   'size',
#   '11pt',
#   'font',
#   'family',
#   'calibri',
#   'img',
#   'border',
#   'src',
#   'https',
#   'selcdn',
#   'ru',
#   'storage',
#   'companies',
#   'company',
#   'inbox',
#   'inbox',
#   'c668eae08f2644f1a362',
#   'jpeg',
#   'p',
#   'td',
#   'td',
#   'style',
#   'font',
#   'size',
#   '11pt',
#   'height',
#   '25px',
#   'font',
#   'family',
#   'calibri',
#   'width',
#   '538px',
#   'valign',
#   'top',
#   'p',
#   'style',
#   'font',
#   'size',
#   '11pt',
#   'font',
#   'family',
#   'calibri',
#   'strong',
#   'иван',
#   'богаш',
#   'strong',
#   'br',
#   'системный',
#   'администратор',
#   'br',
#   'служба',
#   'развитие',
#   'итинфраструктура',
#   'br',
#   'тело',
#   'соты',
#   'br',
#   'e',
#   'mail',
#   'bogash',
#   'i',
#   'dv',
#   'nevada',
#   'ru',
#   'p',
#   'p',
#   'style',
#   'font',
#   'size',
#   '11pt',
#   'f'],
#  ['div', 'dir', 'ltr', 'тест', 'div'],
#  ['style',
#   'font',
#   'definitions',
#   'font',
#   'face',
#   'font',
#   'family',
#   'cambria',
#   'math',
#   'font',
#   'face',
#   'font',
#   'family',
#   'calibri',
#   'style',
#   'definitions',
#   'p',
#   'msonormal',
#   'li',
#   'msonormal',
#   'div',
#   'msonormal',
#   'margin',
#   '0cm',
#   'margin',
#   'bottom',
#   '0001pt',
#   'font',
#   'size',
#   '0pt',
#   'font',
#   'family',
#   'calibri',
#   'sans',
#   'serif',
#   'a',
#   'link',
#   'span',
#   'msohyperlink',
#   'color',
#   '#0563c1',
#   'text',
#   'decoration',
#   'underline',
#   'a',
#   'visited',
#   'span',
#   'msohyperlinkfollowed',
#   'color',
#   '#954f72',
#   'text',
#   'decoration',
#   'underline',
#   'span',
#   'emailstyle17',
#   'font',
#   'family',
#   'calibri',
#   'sans',
#   'serif',
#   'color',
#   'windowtext',
#   'msochpdefault',
#   'font',
#   'family',
#   'calibri',
#   'sans',
#   'serif',
#   'page',
#   'wordsection1',
#   'size',
#   '0pt',
#   '0pt',
#   'margin',
#   '0cm',
#   '5pt',
#   '0cm',
#   '0cm',
#   'div',
#   'wordsection1',
#   'page',
#   'wordsection1',
#   'style',
#   'div',
#   'class',
#   'wordsection1',
#   'p',
#   'class',
#   'msonormal',
#   'тест',
#   'p',
#   'div',
#   'p',
#   'style',
#   'font',
#   'size',
#   '10pt',
#   'font',
#   'family',
#   'arial',
#   'span',
#   'style',
#   'font',
#   'family',
#   'calibri',
#   'span',
#   'style',
#   'font',
#   'size',
#   '11pt',
#   'span',
#   'span',
#   'p',
#   'hr',
#   'br',
#   'table',
#   'style',
#   'width',
#   '660px',
#   'tbody',
#   'tr',
#   'td',
#   'style',
#   'font',
#   'size',
#   '11pt',
#   'height',
#   '25px',
#   'font',
#   'family',
#   'calibri',
#   'width',
#   '122px',
#   'valign',
#   'top',
#   'p',
#   'style',
#   'font',
#   'size',
#   '11pt',
#   'font',
#   'family',
#   'cali',
#   'пинга',
#   'отправить',
#   'iphone',
#   'невад',
#   'группа',
#   'алексей',
#   'оксенич',
#   'руководитель',
#   'группа',
#   'технический',
#   'поддержка',
#   'тело',
#   'соты',
#   'e',
#   'mail',
#   'oksenich',
#   'a',
#   'dv',
#   'nevada',
#   'ru',
#   'оценить',
#   'https',
#   'ru',
#   'surveymonkey',
#   'com',
#   'r',
#   'nevadadv'],
#  ['проверка',
#   'уважение',
#   'гриневич',
#   'дмитрий',
#   'команда',
#   'chat2desk',
#   'com',
#   'aedfaefwef',
#   'уважение',
#   'гриневич',
#   'дмитрий',
#   'команда',
#   'chat2desk',
#   'com',
#   'проверка',
#   'почта',
#   'уважение',
#   'гриневич',
#   'дмитрий',
#   'команда',
#   'chat2desk',
#   'com'],
#  ['уаца', 'цуаца'],
#  ['постоянно',
#   'вылетать',
#   'база',
#   'долго',
#   'грузить',
#   'расчитывать',
#   'остаток',
#   'проводить',
#   'постоянно',
#   'вылетать',
#   'база',
#   'долго',
#   'грузить',
#   'расчитывать',
#   'остаток',
#   'проводить',
#   'прежний',
#   'долго',
#   'проводить',
#   'остаток',
#   'расчитывать',
#   'спасибр'],
#  ['программа', 'висеть', 'выкидывать', 'программа', 'угрюм', 'менее'],
#  ['зависать', 'база', 'весь', 'проводиться', 'медленно', 'хороший'],
#  ['выбрасывать', 'база', 'весь'],
#  ['пко', 'стать'],
#  [''],
#  ['цуаца'],
#  ['уауца'],
#  ['ит', 'dev', 'упасть', 'ожить'],
#  ['весь',
#   'выкинуть',
#   'база',
#   'весь',
#   'норма',
#   'интернет',
#   'отрубиться',
#   'оказаться'],
#  ['касса', 'шмель', 'благовещенск', 'уч', 'запись', 'дегтярев'],
#  ['проба',
#   'перо',
#   'отправить',
#   'iphone',
#   'невад',
#   'группа',
#   'алексей',
#   'оксенич',
#   'руководитель',
#   'группа',
#   'технический',
#   'поддержка',
#   'тело',
#   'соты',
#   'e',
#   'mail',
#   'oksenich',
#   'a',
#   'dv',
#   'nevada',
#   'ru',
#   'оценить',
#   'https',
#   'ru',
#   'surveymonkey',
#   'com',
#   'r',
#   'nevadadv'],
#  ['p',
#   'b',
#   'удаться',
#   'выполнить',
#   'доставка',
#   'следующий',
#   'получатель',
#   'группа',
#   'b',
#   'p',
#   'p',
#   'a',
#   'href',
#   'mailto',
#   'lxqwertxl',
#   'gmail',
#   'com',
#   'lxqwertxl',
#   'gmail',
#   'com',
#   'a',
#   'br',
#   'you',
#   'are',
#   'not',
#   'allowed',
#   'to',
#   'send',
#   'external',
#   'mail',
#   'br',
#   'br',
#   'your',
#   'message',
#   'wasn',
#   't',
#   'delivered',
#   'because',
#   'the',
#   'email',
#   'admin',
#   'for',
#   'the',
#   'organization',
#   'dv',
#   'nevada',
#   'ru',
#   'created',
#   'an',
#   'email',
#   'rule',
#   'restriction',
#   'please',
#   'contact',
#   'the',
#   'email',
#   'admin',
#   'for',
#   'that',
#   'organization',
#   'and',
#   'ask',
#   'them',
#   'to',
#   'remove',
#   'or',
#   'update',
#   'the',
#   'rule',
#   'restriction',
#   'br',
#   'for',
#   'more',
#   'information',
#   'about',
#   'this',
#   'error',
#   'see',
#   'a',
#   'href',
#   'https',
#   'go',
#   'microsoft',
#   'com',
#   'fwlink',
#   'linkid',
#   'dsn',
#   'code',
#   'in',
#   'exchange',
#   'online',
#   'office',
#   'a',
#   'br',
#   'br',
#   'p',
#   'br',
#   'br',
#   'br',
#   'br',
#   'br',
#   'br',
#   'p',
#   'b',
#   'диагностический',
#   'сведение',
#   'администратор',
#   'b',
#   'p',
#   'p',
#   'формировать',
#   'сервер',
#   'mail1',
#   'sweetland',
#   'local',
#   'br',
#   'p',
#   'p',
#   'lxqwertxl',
#   'gmail',
#   'com',
#   'br',
#   'remote',
#   'server',
#   'returned',
#   'transport',
#   'rules',
#   'rejectmessage',
#   'the',
#   'message',
#   'was',
#   'rejected',
#   'by',
#   'organization',
#   'policy',
#   'br',
#   'p',
#   'p',
#   'исходный',
#   'заголовок',
#   'сообщение',
#   'p',
#   'pre',
#   'received',
#   'from',
#   'qweqwe',
#   'by',
#   'mail1',
#   'sweetland',
#   'local',
#   'with',
#   'mi'],
#  ['вмв'],
#  ['укпиупа'],
#  ['кпукп', 'ерп', 'тупить', 'ерп', 'ерп', 'блин'],
#  ['совгавань',
#   'медленно',
#   'ерп',
#   'постоянно',
#   'подвисать',
#   'хороший',
#   'весь',
#   'равно',
#   'подвисать',
#   'заработать',
#   'вновь',
#   'весь',
#   'появиться'],
#  ['эник', 'благовещенск', 'ошибка', 'сфоткать', 'весь'],
#  ['коллега',
#   'нибыть',
#   'ор',
#   'дева',
#   'запустить',
#   'служба',
#   '1с',
#   'весь',
#   'отписаться',
#   'запустить'],
#  ['ерп', 'тупить'],
#  ['кна', 'филиал', 'открываться', 'outlook', 'почта', 'заработать'],
#  ['час',
#   'зайти',
#   'ерп',
#   'посмотреть',
#   'синицын',
#   'татьяна',
#   'имя',
#   'компьютер',
#   'hf',
#   'sd',
#   'помочь',
#   'большой'],
#  ['отладка',
#   'сервер',
#   'база',
#   'srvr',
#   'it',
#   'dev',
#   'ref',
#   'erp2017',
#   'edi',
#   'просить',
#   'помочь',
#   'отладка',
#   'заработать'],
#  ['выгрузка',
#   'марс',
#   'шоколад',
#   'заказ',
#   'марс',
#   'шоколад',
#   'филиал',
#   'сахалин',
#   '—',
#   'заказ',
#   'заказ',
#   'марс',
#   'шоколад',
#   'филиал',
#   'сахалин',
#   '—',
#   'снова',
#   'падать',
#   'заявка',
#   'запрос',
#   'зариф',
#   'васильевский',
#   'чеченский',
#   'яким',
#   'зариф',
#   'васильевский',
#   'чеченский',
#   'яким',
#   '—',
#   'чеченский',
#   'янчевскай',
#   'появиться',
#   'весь',
#   'задвоить'],
#  ['зайти', 'база', 'инфо'],
#  ['касса',
#   'ют',
#   'камчатка',
#   'хотеть',
#   'присваивать',
#   'номер',
#   'пко',
#   'ючуп',
#   'сумма',
#   'присвоить',
#   'номер',
#   'номер',
#   'появиться'],
#  ['ит', 'дева', 'жутко', 'тормозить', 'норма'],
#  ['год', 'артём'],
#  ['прогружаться', 'заказ', 'видеть'],
#  ['торговый',
#   'агент',
#   'приходник',
#   'выгрузиться',
#   'июль',
#   'позвонить',
#   'поправить',
#   'поменять',
#   'поменять',
#   'весь',
#   'нормальный'],
#  ['тест'],
#  ['style',
#   'font',
#   'definitions',
#   'font',
#   'face',
#   'font',
#   'family',
#   'cambria',
#   'math',
#   'font',
#   'face',
#   'font',
#   'family',
#   'calibri',
#   'style',
#   'definitions',
#   'p',
#   'msonormal',
#   'li',
#   'msonormal',
#   'div',
#   'msonormal',
#   'margin',
#   '0cm',
#   'margin',
#   'bottom',
#   '0001pt',
#   'font',
#   'size',
#   '0pt',
#   'font',
#   'family',
#   'calibri',
#   'sans',
#   'serif',
#   'a',
#   'link',
#   'span',
#   'msohyperlink',
#   'color',
#   '#0563c1',
#   'text',
#   'decoration',
#   'underline',
#   'a',
#   'visited',
#   'span',
#   'msohyperlinkfollowed',
#   'color',
#   '#954f72',
#   'text',
#   'decoration',
#   'underline',
#   'span',
#   'emailstyle17',
#   'font',
#   'family',
#   'calibri',
#   'sans',
#   'serif',
#   'color',
#   'windowtext',
#   'msochpdefault',
#   'font',
#   'family',
#   'calibri',
#   'sans',
#   'serif',
#   'page',
#   'wordsection1',
#   'size',
#   '0pt',
#   '0pt',
#   'margin',
#   '0cm',
#   '5pt',
#   '0cm',
#   '0cm',
#   'div',
#   'wordsection1',
#   'page',
#   'wordsection1',
#   'style',
#   'div',
#   'class',
#   'wordsection1',
#   'p',
#   'class',
#   'msonormal',
#   'тест',
#   'p',
#   'div',
#   'p',
#   'style',
#   'font',
#   'size',
#   '10pt',
#   'font',
#   'family',
#   'arial',
#   'span',
#   'style',
#   'font',
#   'family',
#   'calibri',
#   'span',
#   'style',
#   'font',
#   'size',
#   '11pt',
#   'span',
#   'span',
#   'p',
#   'hr',
#   'br',
#   'table',
#   'style',
#   'width',
#   '660px',
#   'tbody',
#   'tr',
#   'td',
#   'style',
#   'font',
#   'size',
#   '11pt',
#   'height',
#   '25px',
#   'font',
#   'family',
#   'calibri',
#   'width',
#   '122px',
#   'valign',
#   'top',
#   'p',
#   'style',
#   'font',
#   'size',
#   '11pt',
#   'font',
#   'family',
#   'cali',
#   'проба',
#   'отправить',
#   'iphone',
#   'невад',
#   'группа',
#   'алексей',
#   'оксенич',
#   'руководитель',
#   'отдел',
#   'технический',
#   'поддержка',
#   'тело',
#   'соты',
#   'e',
#   'mail',
#   'oksenich',
#   'a',
#   'dv',
#   'nevada',
#   'ru',
#   'оценить',
#   'https',
#   'ru',
#   'surveymonkey',
#   'com',
#   'r',
#   'nevadadv'],
#  ['необходимый',
#   'посмотреть',
#   'сканер',
#   'отдел',
#   'координация',
#   'год',
#   'владивосток',
#   'сканировать',
#   'верхний',
#   'лоток',
#   'подождать',
#   'завтра',
#   'весь',
#   'отдел',
#   'продажа',
#   'пользоваться',
#   'наш',
#   'мфу',
#   'отдел',
#   'доставка'],
#  ['намертво',
#   'зависнуть',
#   'сеанс',
#   'erp',
#   'opt',
#   'пользователь',
#   'sweetland',
#   'gilev',
#   'сергей',
#   'савельев',
#   'учётный',
#   'запись',
#   'sweetland',
#   'gilev'],
#  ['body', 'test'],
#  ['ерп', 'висеть'],
#  ['создаваться',
#   'приёмка',
#   'вмс',
#   'проведение',
#   'вычерка',
#   'эксп',
#   'татьяна',
#   'хотеться',
#   'решить',
#   'течение',
#   'получас',
#   'сегодня',
#   'сделать',
#   'заказ',
#   'перемещение',
#   'эоуп',
#   'закрввайте',
#   'написать',
#   'портал',
#   'вероятно',
#   'быстрый',
#   'решение'],
#  ['эник',
#   'благовещенск',
#   'отправить',
#   'фото',
#   'грузиться',
#   'интернет',
#   'слабый',
#   'пошлый',
#   'печать',
#   'напечатать'],
#  ['прогружаться',
#   'заявка',
#   'висеть',
#   'заполниться',
#   'падать',
#   'заявка',
#   'тп',
#   'рындин',
#   'шт',
#   'хватать',
#   'появиться'],
#  ['тест', 'тест', 'тест'],
#  ['прогружаться',
#   'заказ',
#   'медленно',
#   'заказ',
#   'фахурдин',
#   'прогружаться',
#   'извинить'],
#  ['совгавань', 'сформировать', 'касса', 'выдавать', 'ошибка', 'устранить'],
#  ['сохраняться',
#   'попробовать',
#   'друг',
#   'сервер',
#   'база',
#   'развернуть',
#   'возможность',
#   'развернуть',
#   'тестовый',
#   'копия',
#   'бд',
#   'erp',
#   'друг',
#   'сервер',
#   'причём',
#   'несколько',
#   'месяц',
#   'наблюдаться',
#   'хороший',
#   'дождаться',
#   'перезагрузка',
#   'заниматься'],
#  ['заказ',
#   'нажатие',
#   'кнопка',
#   'провести',
#   'срабатывать',
#   'проводиться',
#   'заказ',
#   'проект',
#   'юнилевера',
#   'шт',
#   'валентин',
#   'пробывать',
#   'минута',
#   'назад',
#   'попробовать',
#   'срабатывать',
#   'проводиться',
#   'весь',
#   'сделать'],
#  ['диалог',
#   'диалон',
#   'николай',
#   'диалон',
#   '—',
#   'наличие',
#   'договор',
#   'тт',
#   'врангеля',
#   'находка',
#   'ют',
#   'дв',
#   'ооо',
#   'диалон',
#   'договор',
#   'отгружать',
#   'сэд'],
#  ['подключиться',
#   'свой',
#   'тестовый',
#   'база',
#   'it',
#   'dev',
#   'erp2017',
#   'kotenko',
#   'давать',
#   'познакомиться',
#   'бот',
#   'звать',
#   '—',
#   'катенко',
#   'елена'],
#  ['тест', 'тест', 'весь', 'тест', 'тест', 'спс'],
#  ['кна', 'филиал', 'подключаться', 'программа'],
#  ['отчёт', 'сохранить', 'выбрасывать', 'закрыть', 'получиться'],
#  ['минута',
#   'грузиться',
#   'искать',
#   'документ',
#   'снимать',
#   'отметка',
#   'оскомый',
#   'документ',
#   'обратно',
#   'долго',
#   'грузиться'],
#  ['1с', 'постоянно', 'выкидывать', 'грузиться', 'минута'],
#  ['eqeqqq'],
#  ['пришлый',
#   'управа',
#   'br',
#   'br',
#   'div',
#   'id',
#   'applemailsignature',
#   'отправить',
#   'iphone',
#   'div',
#   'div',
#   'br',
#   'p',
#   'style',
#   'font',
#   'size',
#   '10pt',
#   'font',
#   'family',
#   'arial',
#   'span',
#   'style',
#   'font',
#   'family',
#   'calibri',
#   'span',
#   'style',
#   'font',
#   'size',
#   '11pt',
#   'span',
#   'span',
#   'p',
#   'hr',
#   'br',
#   'table',
#   'style',
#   'width',
#   '660px',
#   'tbody',
#   'tr',
#   'td',
#   'style',
#   'font',
#   'size',
#   '11pt',
#   'height',
#   '25px',
#   'font',
#   'family',
#   'calibri',
#   'width',
#   '122px',
#   'valign',
#   'top',
#   'p',
#   'style',
#   'font',
#   'size',
#   '11pt',
#   'font',
#   'family',
#   'calibri',
#   'img',
#   'border',
#   'src',
#   'https',
#   'selcdn',
#   'ru',
#   'storage',
#   'companies',
#   'company',
#   'inbox',
#   'inbox',
#   'd4e4a0386b2973738c9a',
#   'jpeg',
#   'p',
#   'td',
#   'td',
#   'style',
#   'font',
#   'size',
#   '11pt',
#   'height',
#   '25px',
#   'font',
#   'family',
#   'calibri',
#   'width',
#   '538px',
#   'valign',
#   'top',
#   'p',
#   'style',
#   'font',
#   'size',
#   '11pt',
#   'font',
#   'family',
#   'calibri',
#   'strong',
#   'алексей',
#   'оксенич',
#   'strong',
#   'br',
#   'руководитель',
#   'br',
#   'отдел',
#   'технический',
#   'поддержка',
#   'br',
#   'тело',
#   'соты',
#   'br',
#   'e',
#   'mail',
#   'oksenich',
#   'a',
#   'dv',
#   'nevada',
#   'ru',
#   'p',
#   'p',
#   'style',
#   'font',
#   'size',
#   '11pt',
#   'font',
#   'family',
#   'calibri',
#   'a',
#   'href',
#   'https',
#   'ru',
#   'surveymonkey',
#   'com',
#   'r',
#   'nevadadv',
#   'оценить',
#   'a',
#   'p',
#   'td',
#   'tr',
#   'tbody',
#   'table',
#   'p',
#   'style',
#   'font',
#   'size',
#   '10pt',
#   'font',
#   'family',
#   'проверка',
#   'работа',
#   'почта',
#   'чатбот',
#   'отправить',
#   'iphone',
#   'невад',
#   'группа',
#   'алексей',
#   'оксенич',
#   'руководитель',
#   'отдел',
#   'технический',
#   'поддержка',
#   'тело',
#   'соты',
#   'e',
#   'mail',
#   'oksenich',
#   'a',
#   'dv',
#   'nevada',
#   'ru',
#   'оценить',
#   'https',
#   'ru',
#   'surveymonkey',
#   'com',
#   'r',
#   'nevadadv'],
#  ['закончиться',
#   'срок',
#   'действие',
#   'учётный',
#   'запись',
#   'sweetland',
#   'gilev',
#   'получаться',
#   'писать',
#   'закончить',
#   'срок',
#   'действие',
#   'получиться'],
#  ['касса',
#   'эник',
#   'камчатка',
#   'попытка',
#   'распечатать',
#   'чек',
#   'выдавать',
#   'лента',
#   'кассовый',
#   'аппарат',
#   'отключить',
#   'комп',
#   'включить',
#   'перезагрузка',
#   'касса',
#   'эник',
#   'камчатка',
#   'выдавать',
#   'ошибка',
#   'большой'],
#  ['style',
#   'font',
#   'definitions',
#   'font',
#   'face',
#   'font',
#   'family',
#   'cambria',
#   'math',
#   'font',
#   'face',
#   'font',
#   'family',
#   'calibri',
#   'style',
#   'definitions',
#   'p',
#   'msonormal',
#   'li',
#   'msonormal',
#   'div',
#   'msonormal',
#   'margin',
#   '0cm',
#   'margin',
#   'bottom',
#   '0001pt',
#   'font',
#   'size',
#   '0pt',
#   'font',
#   'family',
#   'calibri',
#   'sans',
#   'serif',
#   'a',
#   'link',
#   'span',
#   'msohyperlink',
#   'color',
#   '#0563c1',
#   'text',
#   'decoration',
#   'underline',
#   'a',
#   'visited',
#   'span',
#   'msohyperlinkfollowed',
#   'color',
#   '#954f72',
#   'text',
#   'decoration',
#   'underline',
#   'span',
#   'emailstyle17',
#   'font',
#   'family',
#   'calibri',
#   'sans',
#   'serif',
#   'color',
#   'windowtext',
#   'msochpdefault',
#   'font',
#   'family',
#   'calibri',
#   'sans',
#   'serif',
#   'page',
#   'wordsection1',
#   'size',
#   '0pt',
#   '0pt',
#   'margin',
#   '0cm',
#   '5pt',
#   '0cm',
#   '0cm',
#   'div',
#   'wordsection1',
#   'page',
#   'wordsection1',
#   'style',
#   'div',
#   'class',
#   'wordsection1',
#   'p',
#   'class',
#   'msonormal',
#   'p',
#   'p',
#   'class',
#   'msonormal',
#   'проверка',
#   'хождение',
#   'почта',
#   'обращать',
#   'внимание',
#   'p',
#   'div',
#   'p',
#   'style',
#   'font',
#   'size',
#   '10pt',
#   'font',
#   'family',
#   'arial',
#   'span',
#   'style',
#   'font',
#   'family',
#   'calibri',
#   'span',
#   'style',
#   'font',
#   'size',
#   '11pt',
#   'span',
#   'span',
#   'p',
#   'hr',
#   'br',
#   'table',
#   'style',
#   'width',
#   '660px',
#   'tbody',
#   'tr',
#   'td',
#   'style',
#   'font',
#   'size',
#   '11pt',
#   'height',
#   '25px',
#   'font',
#   'family',
#   'style',
#   'font',
#   'definitions',
#   'font',
#   'face',
#   'font',
#   'family',
#   'cambria',
#   'math',
#   'font',
#   'face',
#   'font',
#   'family',
#   'calibri',
#   'style',
#   'definitions',
#   'p',
#   'msonormal',
#   'li',
#   'msonormal',
#   'div',
#   'msonormal',
#   'margin',
#   '0cm',
#   'margin',
#   'bottom',
#   '0001pt',
#   'font',
#   'size',
#   '0pt',
#   'font',
#   'family',
#   'calibri',
#   'sans',
#   'serif',
#   'a',
#   'link',
#   'span',
#   'msohyperlink',
#   'color',
#   '#0563c1',
#   'text',
#   'decoration',
#   'underline',
#   'a',
#   'visited',
#   'span',
#   'msohyperlinkfollowed',
#   'color',
#   '#954f72',
#   'text',
#   'decoration',
#   'underline',
#   'p',
#   'margin',
#   'right',
#   '0cm',
#   'margin',
#   'left',
#   '0cm',
#   'font',
#   'size',
#   '0pt',
#   'font',
#   'family',
#   'times',
#   'new',
#   'roman',
#   'serif',
#   'p',
#   'msonormal0',
#   'li',
#   'msonormal0',
#   'div',
#   'msonormal0',
#   'margin',
#   'right',
#   '0cm',
#   'margin',
#   'left',
#   '0cm',
#   'font',
#   'size',
#   '0pt',
#   'font',
#   'family',
#   'times',
#   'new',
#   'roman',
#   'serif',
#   'p',
#   'msochpdefault',
#   'li',
#   'msochpdefault',
#   'div',
#   'msochpdefault',
#   'margin',
#   'right',
#   '0cm',
#   'margin',
#   'left',
#   '0cm',
#   'font',
#   'size',
#   '0pt',
#   'font',
#   'family',
#   'calibri',
#   'sans',
#   'serif',
#   'span',
#   'emailstyle17',
#   'font',
#   'family',
#   'calibri',
#   'sans',
#   'serif',
#   'color',
#   'windowtext',
#   'span',
#   'emailstyle22',
#   'font',
#   'family',
#   'calibri',
#   'sans',
#   'serif',
#   'color',
#   '#1f497d',
#   'msochpdefault',
#   'font',
#   'family',
#   'calibri',
#   'sans',
#   'serif',
#   'page',
#   'wordsection1',
#   'size',
#   '0pt',
#   '0pt',
#   'margin',
#   '0cm',
#   '5pt',
#   '0cm',
#   'style',
#   'font',
#   'definitions',
#   'font',
#   'face',
#   'font',
#   'family',
#   'cambria',
#   'math',
#   'font',
#   'face',
#   'font',
#   'family',
#   'calibri',
#   'style',
#   'definitions',
#   'p',
#   'msonormal',
#   'li',
#   'msonormal',
#   'div',
#   'msonormal',
#   'margin',
#   '0cm',
#   'margin',
#   'bottom',
#   '0001pt',
#   'font',
#   'size',
#   '0pt',
#   'font',
#   'family',
#   'calibri',
#   'sans',
#   'serif',
#   'a',
#   'link',
#   'span',
#   'msohyperlink',
#   'color',
#   '#0563c1',
#   'text',
#   'decoration',
#   'underline',
#   'a',
#   'visited',
#   'span',
#   'msohyperlinkfollowed',
#   'color',
#   '#954f72',
#   'text',
#   'decoration',
#   'underline',
#   'span',
#   'emailstyle17',
#   'font',
#   'family',
#   'calibri',
#   'sans',
#   'serif',
#   'color',
#   'windowtext',
#   'msochpdefault',
#   'font',
#   'family',
#   'calibri',
#   'sans',
#   'serif',
#   'page',
#   'wordsection1',
#   'size',
#   '0pt',
#   '0pt',
#   'margin',
#   '0cm',
#   '5pt',
#   '0cm',
#   '0cm',
#   'div',
#   'wordsection1',
#   'page',
#   'wordsection1',
#   'style',
#   'div',
#   'class',
#   'wordsection1',
#   'p',
#   'class',
#   'msonormal',
#   'тест',
#   'приём',
#   'вложить',
#   'картинка',
#   'обращать',
#   'внимание',
#   'p',
#   'p',
#   'class',
#   'msonormal',
#   'span',
#   'img',
#   'width',
#   'height',
#   'id',
#   'рисунок',
#   'src',
#   'https',
#   'selcdn',
#   'ru',
#   'storage',
#   'companies',
#   'company',
#   'inbox',
#   'inbox',
#   '13f2a7a8f7b219f8b637',
#   'png',
#   'span',
#   'p',
#   'div',
#   'p',
#   'style',
#   'font',
#   'size',
#   '10pt',
#   'font',
#   'family',
#   'arial',
#   'span',
#   'style',
#   'font'],
#  ['div',
#   'dir',
#   'ltr',
#   'тест',
#   'приём',
#   'почта',
#   'внешний',
#   'адрес',
#   'обращать',
#   'внимание',
#   'br',
#   'div'],
#  ['p',
#   'b',
#   'удаться',
#   'выполнить',
#   'доставка',
#   'следующий',
#   'получатель',
#   'группа',
#   'b',
#   'p',
#   'p',
#   'a',
#   'href',
#   'mailto',
#   'werwolf2006',
#   'gmail',
#   'com',
#   'werwolf2006',
#   'gmail',
#   'com',
#   'a',
#   'br',
#   'you',
#   'are',
#   'not',
#   'allowed',
#   'to',
#   'send',
#   'external',
#   'mail',
#   'br',
#   'br',
#   'your',
#   'message',
#   'wasn',
#   't',
#   'delivered',
#   'because',
#   'the',
#   'email',
#   'admin',
#   'for',
#   'the',
#   'organization',
#   'dv',
#   'nevada',
#   'ru',
#   'created',
#   'an',
#   'email',
#   'rule',
#   'restriction',
#   'please',
#   'contact',
#   'the',
#   'email',
#   'admin',
#   'for',
#   'that',
#   'organization',
#   'and',
#   'ask',
#   'them',
#   'to',
#   'remove',
#   'or',
#   'update',
#   'the',
#   'rule',
#   'restriction',
#   'br',
#   'for',
#   'more',
#   'information',
#   'about',
#   'this',
#   'error',
#   'see',
#   'a',
#   'href',
#   'https',
#   'go',
#   'microsoft',
#   'com',
#   'fwlink',
#   'linkid',
#   'dsn',
#   'code',
#   'in',
#   'exchange',
#   'online',
#   'office',
#   'a',
#   'br',
#   'br',
#   'p',
#   'br',
#   'br',
#   'br',
#   'br',
#   'br',
#   'br',
#   'p',
#   'b',
#   'диагностический',
#   'сведение',
#   'администратор',
#   'b',
#   'p',
#   'p',
#   'формировать',
#   'сервер',
#   'mail1',
#   'sweetland',
#   'local',
#   'br',
#   'p',
#   'p',
#   'werwolf2006',
#   'gmail',
#   'com',
#   'br',
#   'remote',
#   'server',
#   'returned',
#   'transport',
#   'rules',
#   'rejectmessage',
#   'the',
#   'message',
#   'was',
#   'rejected',
#   'by',
#   'organization',
#   'policy',
#   'br',
#   'p',
#   'p',
#   'исходный',
#   'заголовок',
#   'сообщение',
#   'p',
#   'pre',
#   'received',
#   'from',
#   'dv',
#   'nevada',
#   'ru',
#   'by',
#   'mail1',
#   'sweetland',
#   'local',
#   'p',
#   'b',
#   'удаться',
#   'выполнить',
#   'доставка',
#   'следующий',
#   'получатель',
#   'группа',
#   'b',
#   'p',
#   'p',
#   'a',
#   'href',
#   'mailto',
#   'werwolf2006',
#   'gmail',
#   'com',
#   'werwolf2006',
#   'gmail',
#   'com',
#   'a',
#   'br',
#   'you',
#   'are',
#   'not',
#   'allowed',
#   'to',
#   'send',
#   'external',
#   'mail',
#   'br',
#   'br',
#   'your',
#   'message',
#   'wasn',
#   't',
#   'delivered',
#   'because',
#   'the',
#   'email',
#   'admin',
#   'for',
#   'the',
#   'organization',
#   'dv',
#   'nevada',
#   'ru',
#   'created',
#   'an',
#   'email',
#   'rule',
#   'restriction',
#   'please',
#   'contact',
#   'the',
#   'email',
#   'admin',
#   'for',
#   'that',
#   'organization',
#   'and',
#   'ask',
#   'them',
#   'to',
#   'remove',
#   'or',
#   'update',
#   'the',
#   'rule',
#   'restriction',
#   'br',
#   'for',
#   'more',
#   'information',
#   'about',
#   'this',
#   'error',
#   'see',
#   'a',
#   'href',
#   'https',
#   'go',
#   'microsoft',
#   'com',
#   'fwlink',
#   'linkid',
#   'dsn',
#   'code',
#   'in',
#   'exchange',
#   'online',
#   'office',
#   'a',
#   'br',
#   'br',
#   'p',
#   'br',
#   'br',
#   'br',
#   'br',
#   'br',
#   'br',
#   'p',
#   'b',
#   'диагностический',
#   'сведение',
#   'администратор',
#   'b',
#   'p',
#   'p',
#   'формировать',
#   'сервер',
#   'mail1',
#   'sweetland',
#   'local',
#   'br',
#   'p',
#   'p',
#   'werwolf2006',
#   'gmail',
#   'com',
#   'br',
#   'remote',
#   'server',
#   'returned',
#   'transport',
#   'rules',
#   'rejectmessage',
#   'the',
#   'message',
#   'was',
#   'rejected',
#   'by',
#   'organization',
#   'policy',
#   'br',
#   'p',
#   'p',
#   'исходный',
#   'заголовок',
#   'сообщение',
#   'p',
#   'pre',
#   'received',
#   'from',
#   'dv',
#   'nevada',
#   'ru',
#   'by',
#   'mail1',
#   'sweetland',
#   'local'],
#  ['торговый', 'агент', 'пко', 'выгрузиться', 'рко', 'весь'],
#  ['падать',
#   'заявка',
#   'тп',
#   'никитин',
#   'александр',
#   'весь',
#   'прислать',
#   'помощь',
#   'требоваться'],
#  ['программа',
#   'еле',
#   'заказ',
#   'еле',
#   'проводиться',
#   'нету',
#   'ошибка',
#   'просто',
#   'проводиться',
#   'заказ',
#   'пять',
#   'минута',
#   'kf',
#   'dp',
#   'kdr2',
#   'сохацкай',
#   'ольга',
#   'большой'],
#  ['минута', 'грузить'],
#  ['тест', 'ага'],
#  ['тест',
#   'тест',
#   'тест',
#   'тест',
#   'тест',
#   'тест',
#   'тест',
#   'тест',
#   'тест',
#   'тест',
#   'тест',
#   'тест',
#   'тест',
#   'тест',
#   'тест',
#   'тест',
#   'тест',
#   'тест',
#   'тест',
#   'тест',
#   'тест',
#   'тест',
#   'тест',
#   'тест'],
#  ['список',
#   'предварительный',
#   'голосование',
#   'каждый',
#   'нужно',
#   'привести',
#   'голосование',
#   'надёжный',
#   'человек',
#   'проголосовать',
#   'глава',
#   'поселение',
#   'шадрина',
#   'плат',
#   'депутат',
#   'собрание',
#   'хабаровский',
#   'район',
#   'бабенко',
#   'плат',
#   'плат',
#   'депутат',
#   'поселение',
#   'романцев',
#   'раздобудько',
#   'ханип',
#   'наш',
#   'год',
#   'увар',
#   'з',
#   'абзал',
#   'метр',
#   'литр',
#   'оксенич',
#   'пьянков',
#   'е',
#   'колесников',
#   'наш',
#   'хомут',
#   'метр',
#   'купуржан',
#   'кокорин',
#   'е',
#   'выходить',
#   'ждать',
#   'пусть',
#   'написать',
#   'пусть',
#   'купить',
#   'хлеб',
#   'тест'],
#  ['тест'],
#  ['случай', 'делать'],
#  ['эгея',
#   'почему',
#   'лк',
#   'видеть',
#   'свой',
#   'сообщение',
#   'плюхнуться',
#   'крюков',
#   'просто',
#   'тестировать'],
#  ['время',
#   'сутки',
#   'сервер',
#   'rn',
#   'bd03',
#   'отсутствовать',
#   'доступ',
#   'хост',
#   'www',
#   'gilev',
#   'ru',
#   'данный',
#   'доступ',
#   'нужный',
#   'анализ',
#   'производительность',
#   'сервер',
#   'просить',
#   'предоставить',
#   'доступ',
#   'доступ',
#   'rn',
#   'bd03',
#   'получиться',
#   'ещё',
#   'нужно',
#   'обновить',
#   'тестовый',
#   'база',
#   'accenicom',
#   'gilev',
#   'сервер',
#   'it',
#   'dev',
#   'последний',
#   'копия',
#   'рабочий',
#   'бд',
#   'accenikom',
#   'поправка',
#   'тестовый',
#   'база',
# ...
#   'ссылка',
#   'почта',
#   'приходить',
#   'подтверждение',
#   'регистрация',
#   'chursina',
#   'iu',
#   'enikom',
#   'ru',
#   'снова',
#   'регистрироваться',
#   'хабаровский',
#   'филиал',
#   'шкотовый',
#   'чурсин',
#   'юлий',
#   'анатолий',
#   'проект',
#   'монделиза',
#   'tds',
#   'менеджер',
#   'развитие',
#   'заявка',
#   'закрыть',
#   'специалист',
#   'помочь',
#   'вопрос',
#   'оператор'],
#  ['развитие',
#   'ооо',
#   'магазин',
#   'семейный',
#   'год',
#   'свободный',
#   'ул',
#   'чубаров',
#   'марс',
#   'корма',
#   'канал',
#   'grocery',
#   'касса',
#   'кв',
#   'метр',
#   'ооо',
#   'развитие',
#   'магазин',
#   'семейный',
#   'год',
#   'свободный',
#   'ул',
#   'чубаров',
#   'марс',
#   'корма',
#   'свободный',
#   'магазин',
#   'широкий',
#   'выбор',
#   'продукт',
#   'питание',
#   'магазин',
#   'касса',
#   'кв',
#   'метр',
#   'магазин',
#   'ип',
#   'чувал',
#   'год',
#   'город',
#   'свободный',
#   'ул',
#   'михайло',
#   'чесноковский',
#   'марс',
#   'корма',
#   'свободный',
#   'магазин',
#   'широкий',
#   'выбор',
#   'продукт',
#   'питание',
#   'канал',
#   'grocery',
#   '1касса',
#   'кв',
#   'метр',
#   'магазин',
#   'маячок',
#   'ип',
#   'разумный',
#   'литр',
#   'год',
#   'город',
#   'свободный',
#   'ул',
#   'михайло',
#   'чесноковский',
#   'марс',
#   'корма',
#   'свободный',
#   'магазин',
#   'широкий',
#   'выбор',
#   'продукт',
#   'питание',
#   'канал',
#   'grocery',
#   'bts',
#   'касса',
#   'кв',
#   'метр',
#   'большой'],
#  ['завести',
#   'договор',
#   'каминский',
#   'согласовать',
#   'каштановый',
#   'ранний',
#   'каштановый',
#   'произойти',
#   'смена',
#   'фамилия',
#   'реквизит',
#   'весь',
#   'остаться',
#   'изменний',
#   'каштановый',
#   'переделать',
#   'каминский',
#   'весь',
#   'документ',
#   'вначале',
#   'проверка',
#   'отправлять',
#   'каминский',
#   'минутка',
#   'ип',
#   'переименоваться',
#   'каминский',
#   'ситуация'],
#  ['поставщик',
#   'гапеев',
#   'сп',
#   'сп',
#   'rbs',
#   'попадать',
#   'позиция',
#   'кодить',
#   'код',
#   'поставщик',
#   'мясной',
#   'дело',
#   'горячее',
#   'деликатес',
#   'сп',
#   'сп'],
#  ['выбрасывать',
#   'программа',
#   'закрыть',
#   'выбрасывать',
#   'норма',
#   'выбрасывать'],
#  ['приходить',
#   'сообщение',
#   'почта',
#   'отправляться',
#   'нормальный',
#   'перезагрузка',
#   'сообщение',
#   'надстройка',
#   'появляться',
#   'значок',
#   'внизу',
#   'весь'],
#  ['просить',
#   'открыть',
#   'заказ',
#   'поставщик',
#   'рц',
#   'код',
#   'товар',
#   'лудин',
#   'павел',
#   'заказать',
#   'пакет',
#   'покупатель',
#   'заявка',
#   'сервис',
#   'деск',
#   'ответ',
#   'товар',
#   'активный'],
#  ['новый',
#   'договор',
#   'юхматовый',
#   'денис',
#   'валентин',
#   'инна',
#   'написать',
#   'ещё',
#   'это',
#   'значит',
#   'заводить',
#   'договор'],
#  ['rbs',
#   'поза',
#   'код340850',
#   'поставщик',
#   'тд',
#   'дальневосточный',
#   'птица',
#   'просить',
#   'внести',
#   'самбрать',
#   'сп',
#   'андрей',
#   'галинский'],
#  ['маркетереть', 'хабаровск'],
#  ['оператор', 'видеть', 'заявка', 'голыгин', 'юнилевера', 'сахалин'],
#  ['добавить',
#   'аналитик',
#   'тт',
#   'тахир',
#   'наш',
#   'з',
#   'контракт',
#   'юнилевера',
#   'нерюнгри',
#   'звать',
#   'анна',
#   'васильев',
#   'small',
#   'supermarkets',
#   '☝',
#   'завести',
#   'координатор',
#   'заводить',
#   'аналитик',
#   'просто',
#   'добавить',
#   'заведение',
#   'контрагент',
#   'аналитик',
#   'выбрать',
#   'чатбот',
#   'заводить',
#   'договор',
#   'чатбот',
#   'весь',
#   'документ',
#   'договор',
#   'отдавать',
#   'координатор',
#   'попробовать'],
#  ['ерп',
#   'нужно',
#   'завести',
#   'новое',
#   'клиент',
#   'ип',
#   'давыденко',
#   'литр',
#   'е',
#   'инна',
#   'юнилевера',
#   'ws',
#   'продукт',
#   'ws',
#   'оптовик',
#   'оптовый',
#   'розничный',
#   'вопрос',
#   'дрбрый',
#   'нужно',
#   'добавить',
#   'точка',
#   'erp',
#   'инна',
#   'ип',
#   'набиев',
#   'оглы',
#   'завести',
#   'новое',
#   'клиент',
#   'ип',
#   'набиев',
#   'оглы',
#   'калинин',
#   'орпка',
#   'пасть',
#   'пригородный',
#   'б',
#   'бородинский',
#   'невад',
#   'юнилевера',
#   'скорый',
#   'заполнить',
#   'суппервайзер',
#   'точка',
#   'вопрос',
#   'завести',
#   'новый',
#   'точка',
#   'ооо',
#   'триада',
#   'делать',
#   'это',
#   'каждый',
#   'весь',
#   'знать'],
#  ['упр',
#   'загружаться',
#   'документ',
#   'загружаться',
#   'ошибка',
#   'проводить',
#   'уйти'],
#  ['упр', 'снова', 'самый', 'весь', 'документ', 'провести'],
#  ['сильно', 'висеть', 'программа', 'вроде', 'норма'],
#  ['учётный',
#   'запись',
#   'снова',
#   'заблокироваться',
#   'просить',
#   'разблокировать',
#   'проверить',
#   'весь',
#   'разблокироваться',
#   'просить',
#   'разблокировать',
#   'учётный',
#   'запись',
#   'вроде',
#   'везде',
#   'перезайти',
#   'заново',
#   'новый',
#   'пароль',
#   'телефон',
#   'удалять',
#   'линк',
#   'узнать',
#   'именно',
#   'блочить',
#   'учеткать',
#   'разблокироваться',
#   'получиться'],
#  ['вызвать', 'специалист'],
#  ['появиться', 'интернет'],
#  ['база',
#   'рбс',
#   'неактиничный',
#   'позиция',
#   'поставщик',
#   'эник',
#   'ооо',
#   'быв',
#   'аметист',
#   'просьба',
#   'активировать',
#   'звать',
#   'людмила',
#   'беспрозвать',
#   'магазин',
#   'самбрать',
#   'весь',
#   'активно'],
#  ['привязать',
#   'точка',
#   'контракт',
#   'майский',
#   'чаять',
#   'точка',
#   'монделиса',
#   'хайнза',
#   'её',
#   'нужно',
#   'привязать',
#   '—',
#   'контракт',
#   'майский',
#   'чаять',
#   'тт',
#   'лембас',
#   'майский',
#   'чаять',
#   'петропавловск',
#   'камчатский',
#   'рынок',
#   'телеграмма',
#   'скачивать',
#   'пробовать'],
#  ['магазин',
#   'эльф',
#   'ооо',
#   'лепрекон',
#   'год',
#   'шимановск',
#   'ул',
#   'пограничный',
#   'марс',
#   'корма',
#   'марс',
#   'шоколад',
#   'свободный',
#   'магазин',
#   'широкий',
#   'выбор',
#   'продукт',
#   'питание',
#   'канал',
#   'grocery',
#   'bts',
#   '2касса',
#   'кв',
#   'метр',
#   'большой'],
#  ['номер',
#   'компьютер',
#   'book',
#   'arc03',
#   'фамилия',
#   'мельник',
#   'татьяна',
#   'доступ',
#   'диск',
#   'd',
#   'давать',
#   'познакомиться',
#   'бот',
#   'звать',
#   'указать',
#   'свой',
#   'имя',
#   'фамилия',
#   '—',
#   'мельник',
#   'татьяна'],
#  ['сегодня',
#   'происходить',
#   'почта',
#   'нормальный',
#   'вчера',
#   'акселот',
#   'выкидывать',
#   'периодически',
#   'вообще',
#   'весь',
#   'сеть',
#   'пропадать',
#   'почта',
#   'линк',
#   'ничто',
#   'почта',
#   'просить',
#   'вчера',
#   'почта',
#   'переполненный',
#   'ящик',
#   '—',
#   'помимо',
#   'ящик',
#   'нормальный',
#   'письмо',
#   'приходить',
#   'опоздание',
#   'исчезать',
#   'входящая',
#   'снова',
#   'появляться',
#   'сегодня',
#   'самый'],
#  ['ип',
#   'коринчук',
#   'е',
#   'визит',
#   'горнозоводск',
#   'шахтовый',
#   'сахалин',
#   'марс',
#   'корма',
#   'продуктовый',
#   'магазин',
#   'балашов',
#   'владимир',
#   'телеграмма',
#   'прогружаться',
#   'соединение',
#   'ужас',
#   'минута',
#   'прекращаться',
#   'приём',
#   'заявка',
#   'час',
#   'присылать',
#   'шаблон',
#   'касса',
#   'площадь',
#   'кв',
#   'метр'],
#  ['коллега', 'сервер', 'отвалиться'],
#  ['1с', 'нык'],
#  ['разобраться', 'тест'],
#  ['пропасть',
#   'доступ',
#   'говорить',
#   'учётный',
#   'запись',
#   'заблокировать',
#   'пользователь',
#   'sweetland',
#   'kozlov',
#   'a'],
#  ['распечатка',
#   'ро',
#   'арма',
#   'выходить',
#   'документ',
#   'менять',
#   'статус',
#   'просить',
#   'удалить',
#   'ро',
#   'уп',
#   'удалить',
#   'весь',
#   'структура',
#   'кроме',
#   'решить'],
#  ['нужно',
#   'получить',
#   'доступ',
#   'бд',
#   'срочно',
#   'решить',
#   'помочь',
#   'сервер',
#   'zup',
#   'corp',
#   'сделать'],
#  ['касса', 'открыть', 'смена'],
#  ['группа',
#   'абд',
#   'самбрать',
#   '1с',
#   'ошибка',
#   'субд',
#   'информация',
#   'получить',
#   'утром',
#   'находиться',
#   'выходной',
#   'соответственно',
#   'магазин',
#   'проверить',
#   'заработать',
#   'отзвониться'],
#  ['склад',
#   'пропасть',
#   'wi',
#   'fi',
#   'зайти',
#   'зайти',
#   'подключение',
#   'интернет',
#   'тсд',
#   'подключаться',
#   'вайфай'],
#  ['звать',
#   'илья',
#   'код',
#   'позиция',
#   'сыр',
#   'сфинкс',
#   'активный',
#   'продажа',
#   'активировать'],
#  ['самбрать',
#   'автозаказ',
#   'попадать',
#   'позиция',
#   'звать',
#   'алёна',
#   'лештаева'],
#  ['группа',
#   'абд',
#   'самбрать',
#   's11',
#   'hms',
#   'удаваться',
#   'войти',
#   'база',
#   'hms',
#   's11',
#   'hms',
#   'терминал',
#   'надпись',
#   'самбрать',
#   'тест',
#   'сервер',
#   'пинговаться',
#   'rdp',
#   'заходить',
#   'весь',
#   'пользователь',
#   'кэш',
#   'очищать',
#   'перезапустить',
#   'служба',
#   '1с',
#   'отключение',
#   'служба',
#   'rphost',
#   'rmngr',
#   'ошибка',
#   'возобновляться',
#   'сохраняться',
#   'короткий',
#   'эллин',
#   'помощник',
#   'са',
#   'изменение',
#   'работа',
#   'база',
#   'восстановить',
#   'снова',
#   'возникнуть',
#   'обращение',
#   'чат',
#   'возобновиться',
#   'группа',
#   'абд',
#   'самбрать',
#   'сервер',
#   's11',
#   'hms',
#   'время',
#   'обнаружение',
#   'ошибка',
#   'удаваться',
#   'войти',
#   'база',
#   'hms',
#   's11',
#   'hms',
#   'терминал',
#   'надпись',
#   'самбрать',
#   'тест',
#   'сервер',
#   'пинговаться',
#   'rdp',
#   'заходить',
#   'сервер',
#   'перезагрузить',
#   'перезапустить',
#   'служба',
#   '1с',
#   'отключение',
#   'служба',
#   'rphost',
#   'rmngr',
#   'весь',
#   'пользователь',
#   'кэш',
#   'очищать',
#   'ошибка',
#   'возобновиться',
#   'перезагрузка',
#   'сервер',
#   'короткий',
#   'эллин',
#   'помощник',
#   'са',
#   'подтверждать',
#   'наблюдаться'],
#  ['зайти',
#   'рабочий',
#   'ноутбук',
#   'орельский',
#   'директор',
#   'логистика',
#   'рн',
#   'орельский',
#   'андрей'],
#  ['бот',
#   'ассортимент',
#   'сегмент',
#   'поставщик',
#   'владивосток',
#   'перенести',
#   'поставщик',
#   'компания',
#   'арсенал',
#   'рбс',
#   'товар',
#   'привязать',
#   'владивосток',
#   'фото',
#   'ниже'],
#  ['группа',
#   'абд',
#   'самбрать',
#   'обмен',
#   'выгружаться',
#   'локальный',
#   'распродажа',
#   'прилететь',
#   'установка',
#   'снятие',
#   'промый',
#   'цена',
#   'обнаружить',
#   'минута',
#   'назад',
#   'магазин',
#   'находиться',
#   'поздний',
#   'сотрудник',
#   'сделать',
#   'заявка',
#   'скинуть',
#   'номер',
#   'обращение',
#   'просить',
#   'проверить',
#   'отправить',
#   'ребут',
#   'загрузиться',
#   'телефон',
#   'дом',
#   'мониторить',
#   'телефон',
#   'год',
#   'поднимать',
#   'подождать',
#   'цена',
#   'прилететь'],
#  ['rbs',
#   'попадать',
#   'код',
#   'товар',
#   'беларусь',
#   'сегодня',
#   'завтра',
#   'нужно',
#   'сделать',
#   'заказ',
#   'просить',
#   'помочь',
#   'самбрать',
#   'позиция',
#   'ещё',
#   'появиться',
#   'позиция',
#   'появиться',
#   'заказ',
#   'выгрузиться',
#   'цена',
#   '1с'],
#  ['код',
#   'попадать',
#   'атозаказ',
#   'девять',
#   'магазин',
#   'матрица',
#   'цуа',
#   'весь',
#   'проставить',
#   'куприн',
#   'илья',
#   'это',
#   'магазин',
#   'скинуть',
#   'информация',
#   'отправить',
#   'имя',
#   'проверить',
#   'радость',
#   'сообщить',
#   'вчера',
#   'сегодня',
#   'прийти',
#   'офис',
#   'понять',
#   'это',
#   'отправить',
#   'отправить',
#   'запрос',
#   'магазин',
#   'скорее',
#   'ответ',
#   'получить',
#   'ток',
#   'завтра',
#   'активный',
#   'горох',
#   'пащенко',
#   'пащенко',
#   'изначально',
#   'пащенко',
#   'сегодня',
#   'поменять',
#   'исправить',
#   'сегодня',
#   'возможно',
#   'прошол',
#   'обмен',
#   'отправить',
#   'магазин',
#   'ответить',
#   'отписаться'],
#  ['это', 'арсенал', 'это', 'владивосток', 'измениться', 'нечего', 'зменилось'],
#  ['валерий',
#   'соколов',
#   'привязка',
#   'поддон',
#   'распоряжение',
#   'появляться',
#   'ошибка',
#   'просить',
#   'подсказать',
#   'посмотреть',
#   'данный',
#   'самбрать',
#   'манипуляция',
#   'появляться',
#   'ошибка',
#   'ещё',
#   'появиться',
#   'ошибка',
#   'редактирование',
#   'профиль',
#   'полный',
#   'скрин',
#   'прилагать',
#   'просить',
#   'помочь',
#   'очистить',
#   'весь',
#   'папка',
#   'планироваться',
#   'либо',
#   'работа',
#   'база',
#   'hms',
#   'просить',
#   'отложить',
#   'сегодня',
#   'проводиться',
#   'сплошной',
#   'инвентаризация'],
#  ['запускаться',
#   'системный',
#   'блок',
#   'никакой',
#   'реакция',
#   'включение',
#   'находиться',
#   'павел',
#   'морозов',
#   'рабочий',
#   'место',
#   'a4',
#   'сергей',
#   'филипченко'],
#  ['тест', 'тест', 'тест', 'тест'],
#  ['заблокировать',
#   'учётный',
#   'запись',
#   'пользователь',
#   'вход',
#   'сеть',
#   'васин',
#   'дмитрий',
#   'забыть',
#   'пароль',
#   'сделать',
#   'новый'],
#  ['нужно', 'привязать', 'общий', 'прайс', 'договор', 'весь', 'понятно'],
#  ['ага', 'понять'],
#  ['отлично', 'сбой'],
#  ['ток',
#   'получить',
#   'магазин',
#   'нету',
#   'горох',
#   'жаловаться',
#   'ждать',
#   'обмен'],
#  ['добро',
#   'доступный',
#   'тестовый',
#   'контур',
#   'вероятный',
#   'сеть',
#   'список',
#   'сервер',
#   'rn',
#   'bd',
#   'test',
#   'smk',
#   'conf',
#   'rn',
#   'bd02',
#   'test',
#   'rn',
#   'bd03',
#   'test',
#   'rn',
#   'bd04',
#   'test',
#   'вопрос',
#   'критичный',
#   'сегодня',
#   'релиз',
#   'выгрузка',
#   'рабочий',
#   'зайти',
#   'дотестировать',
#   'многий',
#   'возможно',
#   'число',
#   'юдин',
#   'кирилл',
#   'подняться',
#   'спаибо'],
#  ['чайковский',
#   'марс',
#   'корма',
#   'марс',
#   'шоколад',
#   'ферреро',
#   'прогресс',
#   'вбд',
#   'ваннмелла',
#   'розница',
#   'традиционный',
#   'продуктовый',
#   'магазин',
#   'потапов',
#   'юлий'],
#  ['активировать',
#   'точка',
#   'нагибин',
#   'ип',
#   'магазин',
#   'столичный',
#   'город',
#   'холмск',
#   'ул',
#   'ленин',
#   'город',
#   'холмск',
#   'ул',
#   'победа',
#   '28а',
#   'феррейро',
#   'сахалин',
#   'писать',
#   'сэд',
#   'найти',
#   'договор',
#   'инна',
#   'попробовать',
#   'ещё',
#   'правильно',
#   'феррейро',
#   'весь',
#   'получиться',
#   'весь',
#   'получиться',
#   'срасибо',
#   'узнать',
#   'отгружать',
#   'точка',
#   'бот',
#   'писать',
#   'контрагент',
#   'отправить',
#   'erp',
#   'ферреро',
#   'сахалин',
#   'нагибин',
#   'ип',
#   'столичный',
#   'город',
#   'холмск',
#   'ул',
#   'ленин',
#   'сколько',
#   'ждать',
#   'время',
#   'весь',
#   'заполнить',
#   'это',
#   'весь',
#   'выдавать',
#   'повторно',
#   'делать',
#   'ждать',
#   'часы',
#   'весь',
#   'заполнить'],
#  ['тормозить',
#   'тсд',
#   'виснуть',
#   'вмс',
#   'метр',
#   'арц',
#   'готовый',
#   'весь',
#   'выйти',
#   'пробовать',
#   'весь'],
#  [''],
#  ['смк',
#   'группа',
#   'абд',
#   'оформить',
#   'обращение',
#   'ведомость',
#   'вщаиморасчёт',
#   'сотрудник',
#   'формироваться',
#   'рко',
#   'выдача',
#   'зп',
#   'каждый',
#   'месяц',
#   'понимать',
#   'ку',
#   'щаходить',
#   'документ',
#   'проверять',
#   'платёжный',
#   'ведомость',
#   'печатать',
#   'корпортал',
#   'щаявка',
#   'коркино',
#   'оксана',
#   'рамка',
#   'портал',
#   'взять',
#   'работа',
#   'переходить',
#   'кп'],
#  ['зависать',
#   'почта',
#   'нужно',
#   'перепрописать',
#   'профиль',
#   'почистить',
#   'кэш'],
#  ['вещевой', 'довольствие', 'ревизор', 'номер', 'заявка', 'эп', 'василий'],
#  ['группа',
#   'тп',
#   'аз',
#   'с3',
#   's3',
#   'az01',
#   'обнаружить',
#   'работа',
#   'аз',
#   'периодичность',
#   'появляться',
#   'ошибка',
#   'возможность',
#   'зайти',
#   'база',
#   'аз',
#   'сообщить',
#   'преблизительный',
#   'время',
#   'выполнение',
#   'вроде',
#   'серверный',
#   'группа',
#   'с3',
#   'wi',
#   'fi',
#   'samberito',
#   'последний',
#   'проверка'],
#  ['касса',
#   'ют',
#   'камчатка',
#   'выдавать',
#   'ошибка',
#   'весь',
#   'большой',
#   'касса',
#   'ют',
#   'камчатка',
#   'выдавать',
#   'ошибка',
#   'весь'],
#  ['смк',
#   'группа',
#   'абд',
#   'заявка',
#   'несколько',
#   'майоров',
#   'са',
#   'иван',
#   'майоров'],
#  ['https',
#   'web',
#   'whatsapp',
#   'com',
#   'send',
#   'phone',
#   'https',
#   'web',
#   'whatsapp',
#   'com',
#   'send',
#   'phone'],
#  ['юнилевера',
#   'иванчук',
#   'инна',
#   'эник',
#   'бот',
#   'заполнить',
#   'требовать',
#   'аналитик',
#   'торговый',
#   'точка',
#   'нагибин',
#   'гастроном',
#   'год',
#   'долинск',
#   'комсомольский',
#   'ул',
#   'дом',
#   'номер',
#   'нагибин',
#   'столичный',
#   'год',
#   'долинск',
#   'комсомольский',
#   'ул',
#   'номер',
#   'иванчук',
#   'вера',
#   'взломать',
#   'телефон',
#   'это',
#   'пользоваться',
#   'телеграф',
#   'дать',
#   'ваш',
#   'номер',
#   'написать',
#   'юнилевера',
#   'ип',
#   'нагибин',
#   'год',
#   'долинск',
#   'комсомольский',
#   'инна',
#   'территория',
#   'сахалин',
#   'канал',
#   'сбыт',
#   'минимаркета',
#   'специализация',
#   'продукт',
#   'питание',
#   'кола',
#   'касс3',
#   'площадь',
#   'ип',
#   'нагибин',
#   'год',
#   'долинск',
#   'комсомольский',
#   'инна',
#   'территория',
#   'сахалин',
#   'канал',
#   'сбыт',
#   'минимаркета',
#   'специализация',
#   'продукт',
#   'питание',
#   'кола',
#   'касс3',
#   'площадь'],
#  ['программа', 'выбрасывать'],
#  ['удаваться',
#   'дом',
#   'подключиться',
#   'рабочий',
#   'пк',
#   'ранее',
#   'доступ',
#   'удалённый',
#   'подключение',
#   'дом',
#   'максим',
#   'лупекин',
#   'получаться',
#   'пароль',
#   'уверенный',
#   'вводить',
#   'верно'],
#  ['маркетереть', 'хабаровск', 'весь'],
#  ['помочь',
#   'заполнение',
#   'аналитик',
#   'плат',
#   'бюргер',
#   'далее',
#   'новороссия',
#   'ул',
#   'первомайский',
#   'договор',
#   'торговый',
#   'точка',
#   'заводила',
#   'ещё',
#   'бот',
#   'некорректно',
#   'говорят',
#   'договор',
#   'найти',
#   'аналитик',
#   'заполнить',
#   'знать',
#   'делать',
#   'марс',
#   'корма'],
#  ...]

# %%
data.head(3)
# Out:
#                                                                                                                    mesTExt
# 0
# 1  сломаться ноготь сломать ноготь сломать ноготь сломаться ноутбук весь пропасть делать вообще чушь помочь срочно вооб...
# 2                                                                хабаровск сломаться ноутбук рабртаять автозаказ автозаказ
